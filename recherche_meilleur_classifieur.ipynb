# %% [markdown]
# # Importation des modules

# %%
###### modules pour le chargement des données depuis le XML ######
import glob
from lxml import etree
from preTraitements.xml import get_X_Y_from_root
from preTraitements.xml import get_tree_root_from_file

###### modules pour la classification ######

# modèles
from sklearn.svm import LinearSVC, SVC

# vectorisation
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.preprocessing import StandardScaler

# création de nos transformers
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.preprocessing import FunctionTransformer
from sklearn.feature_extraction import DictVectorizer # créer nos propres transformer
#%pip install transformers[sentencepiece]
#%pip install torch
from transformers import pipeline

# recherche des meilleurs hyperparamètres
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV

# résultats
from sklearn.metrics import classification_report

# sauvegarde des modèles
from joblib import dump, load

###### modules pour la visualisation ######
import matplotlib.pyplot as plt
import pandas as pd

###### miscellaneous ######
from typing import List # typage des fonctions
import numpy as np
import re
from collections import namedtuple

# %% [markdown]
# # Pré-traitement des données
#
# ## Chargement des données dans le bon format

# %%
tree_train, root_train = get_tree_root_from_file("./corpus/train_deft09_parlement_appr.xml/deft09_parlement_appr_fr.xml")
X_train, y_train = get_X_Y_from_root(root_train)

tree_test, root_test = get_tree_root_from_file("./corpus/deft09_parlement_test.xml/deft09_parlement_test_fr.xml")
X_test, y_test = get_X_Y_from_root(root_test) # y_test est vide : pas accès aux résultats

# %%
import re
pattern = re.compile(r'\d+\t(\w+(-\w+)?)')
y_test = []
folder =  "/content/drive/My Drive/Colab Notebooks/Apprentissage_Artificiel/corpus"
files_ref = glb.glob(folder+"/deft09_parlement_ref/deft09_parlement_ref_fr.txt")
for file in files_ref:
  input = file
with open(input,'r') as file:
    line = file.readline()
    while line:
        m= re.match(pattern,line)
        if m:
            y_test.append(m.group(1))
        else:
            y_test.append('PSE')
        line = file.readline()

# %%
from sklearn.preprocessing import LabelBinarizer, LabelEncoder

# Créer un objet LabelBinarizer
lb = LabelEncoder()

# Convertir les étiquettes de classe en un tableau binaire
y_train_bin = lb.fit_transform(y_train)
y_test_bin = lb.fit_transform(y_test)

# %% [markdown]
# ## Nettoyage des données

# %%
pattern_clean = re.compile(r"[^ \w]") # pattern à utiliser pour nettoyer les données

def clean(data:list)->list: 
    """
    Cette fonction renvoie une liste de string nettoyé. 
    Les caractères sont transformés en minuscule et on ne garde que le token.
    Toute la ponctuation est retirée.

    Args:
        data (_type_): liste de string

    Returns:
        _type_: liste de string
    """
    global pattern_clean
    return re.sub(pattern_clean, "", data).lower()

X_train_clean = [clean(x) for x in X_train]
X_test_clean = [clean(x) for x in X_test]

# %% [markdown]
# # Extraction des features

# %% [markdown]
# ## GloVe

# %%
import glob
import os
#root folder
root_folder='.'
glove_filename='vectors/vectors.txt'

# Variable for data directory
glove_path = os.path.abspath(glove_filename)
# Out:
# '/content/drive/My Drive/Colab Notebooks/Apprentissage_Artificiel/vectors.txt'

# %%
from gensim.models import KeyedVectors
word2vec_output_file = glove_filename+'.word2vec'
glove = KeyedVectors.load_word2vec_format(word2vec_output_file, binary=False)

# %%
#remplace un CountVectorizer()
def GloveVectorizer(X_train):
    model = glove
    n=0
    m = glove.get_vector('président')
    docs = np.zeros((len(X_train),m.shape[0]))
    for document in X_train:
        word_vectors=[]
        for token in document.split():
            if token in model:
                word_vectors.append(model[token])
        if len(word_vectors)>0:
            word_vectors = np.array(word_vectors)
            docs[n]=word_vectors.mean(axis=0)
        else:
            docs[n]=np.zeros(m.shape[0])
        n=n+1
    return docs

# %% [markdown]
# ## Word2vec

# %%
w2v_filename='vectors/text8-vector.bin'

# Variable for data directory
w2v_path = os.path.abspath(w2v_filename)

wv_from_bin = KeyedVectors.load_word2vec_format(w2v_path, binary=True)
def w2vVectorizer(X_train):
    model = wv_from_bin
    n=0
    m = wv_from_bin.get_vector('président')
    docs = np.zeros((len(X_train),m.shape[0]))
    for document in X_train:
        word_vectors=[]
        for token in document.split():
            if token in model:
                word_vectors.append(model[token])
        if len(word_vectors)>0:
            word_vectors = np.array(word_vectors)
            docs[n]=word_vectors.mean(axis=0)
        else:
            docs[n]=np.zeros(m.shape[0])       
        n=n+1
    return docs

# %% [markdown]
# ## FastText

# %%
#########pas possible ! cf le github fasttext pour le faire en ligne de commande
from gensim.models import KeyedVectors
from gensim.test.utils import datapath
from gensim.models.fasttext import load_facebook_vectors
fde = '../cc.fr.300.bin' #modèle disponible sur le site de fasttext
ft_path = os.path.abspath(fde)
print(ft_path)
model = load_facebook_vectors(fde)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-70-dee8ee530ce8> in <module>
#       2 from gensim.models import KeyedVectors
#       3 from gensim.test.utils import datapath
# ----> 4 from gensim.models.fasttext import load_facebook_vectors
#       5 #from gensim.models import fasttext.load_facebokk_vectors
#       6 fde = '../../Documents/fastText/cc.fr.300.bin'
#
# ImportError: cannot import name 'load_facebook_vectors' from 'gensim.models.fasttext' (/usr/local/lib/python3.8/dist-packages/gensim/models/fasttext.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
def FTVectorizer(X_train):
    global model
    n=0
    m = model.get_vector('président')
    docs = np.zeros((len(X_train),m.shape[0]))
    for document in X_train:
        word_vectors=[]
        for token in document.split():
            if token in model:
                word_vectors.append(model[token])
        if len(word_vectors)>0:
            word_vectors = np.array(word_vectors)
            docs[n]=word_vectors.mean(axis=0)
        n=n+1
    return docs

# %% [markdown]
# ## Transformers personnalisés
#
# Les transformers personnalisés sont disponibles dans les fichiers `add_features.ipynb`

# %% [markdown]
# # Création des PipeLine
#
# on crée d'abord toutes les pipelines qu'on veut
#
# on aura une param_grid par pipeline

# %%
liste_clfs = []

# %%
# named tuple Classifieur : 
# - pipeline
# - param_grid pour le grid_search
Classifieur = namedtuple('Classifieur', ["pipeline", "param_grid"]) #TODO : instancier le nom du classifieur pour que ça soit facile à récupérer après

# %% [markdown]
# ## `LinearSVC()`

# %%
liste_svc = []

# %% [markdown]
# ### Avec CountVectorizer()

# %%
# liste de tuples nommés Classifieur(pipeline, param_grid)
from sklearn.svm import LinearSVC
pipeline_svm = Pipeline([
        ('ngram_tf_idf', Pipeline([
          ('counts', CountVectorizer(min_df=1, ngram_range=(1,1))),
          ('tf_idf', TfidfTransformer(sublinear_tf=True))
        ])),
  ('standard', StandardScaler(with_mean=False)),
  #('svm', SVC(probability=True,kernel = 'linear',class_weight='balanced'))])
  ('svm', LinearSVC(class_weight='balanced',max_iter=10000))])
param_grid_svm = {
    "ngram_tf_idf__counts__stop_words":('french',None), #TODO: pas de french : utiliser la liste de spacy ou nltk
    "ngram_tf_idf__tf_idf__use_idf":(True,False),
    "ngram_tf_idf__tf_idf__sublinear_tf":(True,False),
    "svm__kernel":('linear', 'poly', 'rbf'),
    "svm__class_weight":('balanced',None),
    "svm__C":(0.1,0.5) # complexité du modèle
    }

svm = Classifieur(pipeline_svm, param_grid_svm)
liste_svc.append(svm)

# %% [markdown]
# ### Avec GloveVectorizer()

# %%
# liste de tuples nommés Classifieur(pipeline, param_grid)
pipeline_svm = Pipeline([
        ('ngram_tf_idf', Pipeline([
          ('counts', FunctionTransformer(GloveVectorizer)),
          #('tf_idf', TfidfTransformer())
        ])),
  #('standard', StandardScaler(with_mean=False)),
  #('svm', SVC(probability=True,kernel = 'linear',class_weight='balanced'))])
  ('svm', OneVsOneClassifier(LinearSVC(class_weight='balanced',max_iter=10000,C=0.5)))])

param_grid_svm = {
    #"ngram_tf_idf__counts__stop_words":('french',None), #TODO: pas de french : utiliser la liste de spacy ou nltk
    #"ngram_tf_idf__tf_idf__use_idf":(True,False),
    #"ngram_tf_idf__tf_idf__sublinear_tf":(True,False),
    #"svm__kernel":('linear', 'poly', 'rbf'),
    #svm__class_weight":('balanced',None),
    #"svm__C":(0.1,0.5) # complexité du modèle
    }


liste_svc.append(pipeline_svm)

# %% [markdown]
# ### Avec Word2Vec

# %%
# liste de tuples nommés Classifieur(pipeline, param_grid)
pipeline_svm = Pipeline([
        ('ngram_tf_idf', Pipeline([
          ('counts', FunctionTransformer(w2vVectorizer)),
          #('tf_idf', TfidfTransformer())
        ])),
  #('standard', StandardScaler(with_mean=False)),
  #('svm', SVC(probability=True,kernel = 'linear',class_weight='balanced'))])
  ('svm', OneVsOneClassifier(LinearSVC(class_weight='balanced',max_iter=10000,C=0.1)))])

param_grid_svm = {
    #"ngram_tf_idf__counts__stop_words":('french',None), #TODO: pas de french : utiliser la liste de spacy ou nltk
    #"ngram_tf_idf__tf_idf__use_idf":(True,False),
    #"ngram_tf_idf__tf_idf__sublinear_tf":(True,False),
    #"svm__kernel":('linear', 'poly', 'rbf'),
    #svm__class_weight":('balanced',None),
    #"svm__C":(0.1,0.5) # complexité du modèle
    }

liste_svc.append(pipeline_svm)

# %% [markdown]
# ### Test

# %%
best_models_w2v = []
from sklearn.preprocessing import LabelEncoder

# Créer un objet LabelBinarizer
lb = LabelEncoder()

# Convertir les étiquettes de classe en un tableau binaire
y_train_bin = lb.fit_transform(y_train)
y_test_bin = lb.fit_transform(y_test)
for (pipeline, param_grid) in liste_svc:
    print("="*80)
    grid_search = GridSearchCV(pipeline, param_grid=param_grid,verbose=10)
    estimator = grid_search.fit(X_train_clean, y_train_bin)
    best_models_w2v.append(estimator)
    print("="*80,'\n')
# Out:
# ================================================================================
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV 1/5; 1/2] START svm__C=0.1..................................................
# [CV 1/5; 1/2] END ...................svm__C=0.1;, score=0.344 total time=  22.3s
# [CV 2/5; 1/2] START svm__C=0.1..................................................
# [CV 2/5; 1/2] END ...................svm__C=0.1;, score=0.341 total time=  16.3s
# [CV 3/5; 1/2] START svm__C=0.1..................................................
# [CV 3/5; 1/2] END ...................svm__C=0.1;, score=0.354 total time=  16.6s
# [CV 4/5; 1/2] START svm__C=0.1..................................................
# [CV 4/5; 1/2] END ...................svm__C=0.1;, score=0.336 total time=  17.0s
# [CV 5/5; 1/2] START svm__C=0.1..................................................
# [CV 5/5; 1/2] END ...................svm__C=0.1;, score=0.352 total time=  19.3s
# [CV 1/5; 2/2] START svm__C=0.5..................................................
# [CV 1/5; 2/2] END ...................svm__C=0.5;, score=0.346 total time=  31.0s
# [CV 2/5; 2/2] START svm__C=0.5..................................................
# [CV 2/5; 2/2] END ...................svm__C=0.5;, score=0.345 total time=  29.9s
# [CV 3/5; 2/2] START svm__C=0.5..................................................
# [CV 3/5; 2/2] END ...................svm__C=0.5;, score=0.350 total time=  28.1s
# [CV 4/5; 2/2] START svm__C=0.5..................................................
# [CV 4/5; 2/2] END ...................svm__C=0.5;, score=0.337 total time=  24.3s
# [CV 5/5; 2/2] START svm__C=0.5..................................................
# [CV 5/5; 2/2] END ...................svm__C=0.5;, score=0.353 total time=  23.9s
# ================================================================================
#
# ================================================================================
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV 1/5; 1/2] START svm__C=0.1..................................................
# [CV 1/5; 1/2] END ...................svm__C=0.1;, score=0.383 total time= 1.8min
# [CV 2/5; 1/2] START svm__C=0.1..................................................
# [CV 2/5; 1/2] END ...................svm__C=0.1;, score=0.370 total time= 1.7min
# [CV 3/5; 1/2] START svm__C=0.1..................................................
# [CV 3/5; 1/2] END ...................svm__C=0.1;, score=0.387 total time= 1.6min
# [CV 4/5; 1/2] START svm__C=0.1..................................................
# [CV 4/5; 1/2] END ...................svm__C=0.1;, score=0.379 total time= 1.5min
# [CV 5/5; 1/2] START svm__C=0.1..................................................
# [CV 5/5; 1/2] END ...................svm__C=0.1;, score=0.394 total time= 1.5min
# [CV 1/5; 2/2] START svm__C=0.5..................................................
# [CV 1/5; 2/2] END ...................svm__C=0.5;, score=0.382 total time= 8.3min
# [CV 2/5; 2/2] START svm__C=0.5..................................................
# [CV 2/5; 2/2] END ...................svm__C=0.5;, score=0.371 total time= 7.5min
# [CV 3/5; 2/2] START svm__C=0.5..................................................
# [CV 3/5; 2/2] END ...................svm__C=0.5;, score=0.386 total time= 7.7min
# [CV 4/5; 2/2] START svm__C=0.5..................................................
# [CV 4/5; 2/2] END ...................svm__C=0.5;, score=0.380 total time= 8.7min
# [CV 5/5; 2/2] START svm__C=0.5..................................................
# [CV 5/5; 2/2] END ...................svm__C=0.5;, score=0.393 total time= 7.4min
# ================================================================================

# %%
for m in liste_svc:
  model = m
  m.fit(X_train_clean,y_train_bin)
  y_pred = m.predict(X_test_clean)
  print(classification_report(y_test_bin, y_pred))
  print("="*80)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.17      0.31      0.22      1339
#            1       0.33      0.58      0.42      1793
#            2       0.45      0.21      0.29      4571
#            3       0.38      0.28      0.32      3629
#            4       0.18      0.27      0.22      1585
#
#     accuracy                           0.30     12917
#    macro avg       0.30      0.33      0.29     12917
# weighted avg       0.35      0.30      0.30     12917
#
# ================================================================================
#               precision    recall  f1-score   support
#
#            0       0.21      0.43      0.28      1339
#            1       0.45      0.60      0.51      1793
#            2       0.53      0.29      0.38      4571
#            3       0.42      0.31      0.36      3629
#            4       0.25      0.40      0.31      1585
#
#     accuracy                           0.37     12917
#    macro avg       0.37      0.41      0.37     12917
# weighted avg       0.42      0.37      0.37     12917
#
# ================================================================================

# %% [markdown]
#           precision    recall  f1-score   support
#
#            0       0.17      0.31      0.22      1339
#            1       0.33      0.58      0.42      1793
#            2       0.45      0.21      0.29      4571
#            3       0.38      0.28      0.32      3629
#            4       0.18      0.27      0.22      1585
#
#     accuracy                           0.30     12917
#    macro avg       0.30      0.33      0.29     12917
# weighted avg       0.35      0.30      0.30     12917
#
# ================================================================================
#               precision    recall  f1-score   support
#
#            0       0.21      0.43      0.28      1339
#            1       0.45      0.60      0.51      1793
#            2       0.53      0.29      0.38      4571
#            3       0.42      0.31      0.36      3629
#            4       0.25      0.40      0.31      1585
#
#     accuracy                           0.37     12917
#    macro avg       0.37      0.41      0.37     12917
# weighted avg       0.42      0.37      0.37     12917
#
# ================================================================================

# %%
for clf, estimator in zip(['CountVec','glove','word2vec'],best_models_w2v):
  pd_estimator = pd.DataFrame.from_dict(estimator.cv_results_)
  pd_estimator = pd_estimator.sort_values(by="rank_test_score", ascending=True)
  pd_estimator.to_csv(f"{clf}_cvresults_all.csv")

# %% [markdown]
# ## `KNN`

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.feature_selection import SelectKBest
from sklearn.impute import SimpleImputer

# %%
liste_knn = []

# %% [markdown]
# ### Avec CountVectorizer

# %%
from sklearn.neighbors import KNeighborsClassifier

# liste de tuples nommés Classifieur(pipeline, param_grid)
pipeline_knn = Pipeline([
        ('ngram_tf_idf', Pipeline([
          ('counts', CountVectorizer()),
          ('tf_idf', TfidfTransformer(use_idf=False,sublinear_tf=True))
        ])),
  ('in',SimpleImputer(strategy='mean')),
  ('select',SelectKBest()),
  #('standard', StandardScaler(with_mean=False)),
  ('knn', KNeighborsClassifier())])

param_grid_knn = {
    "ngram_tf_idf__counts__ngram_range": ((1, 1), (2,2)),  # unigrams or bigrams
    #"ngram_tf_idf__counts__stop_words":('french',None), #TODO: pas de french : utiliser la liste de spacy ou nltk
    #"ngram_tf_idf__tf_idf__use_idf":(True,False),
    #"ngram_tf_idf__tf_idf__sublinear_tf":(True,False),
    "knn__algorithm":('auto', 'brute'),
    "knn__n_neighbors":(1,2,3,4,5),
    "select__k":(100,200,500,1000)
    }

knn = Classifieur(pipeline_knn, param_grid_knn)
liste_knn.append(knn)

# %% [markdown]
# ### Avec GloveVectorizer

# %%
# liste de tuples nommés Classifieur(pipeline, param_grid)
pipeline_knn = Pipeline([
        ('ngram_tf_idf', Pipeline([
          ('counts', FunctionTransformer(GloveVectorizer)),
          ('tf_idf', TfidfTransformer()),
        ])),
  #('in',SimpleImputer(strategy='mean')),
  ('select',SelectKBest()),
  #("min",MinMaxScaler()),
  ('knn', KNeighborsClassifier())])

param_grid_knn = {
    #"ngram_tf_idf__counts__stop_words":('french',None), #TODO: pas de french : utiliser la liste de spacy ou nltk
    "ngram_tf_idf__tf_idf__use_idf":(True,False),
    #"ngram_tf_idf__tf_idf__sublinear_tf":(True,False),
    "knn__algorithm":('auto', 'brute'),
    "select__k":(10,20,50),
    "knn__n_neighbors":(2,5)
    }

knn = Classifieur(pipeline_knn, param_grid_knn)
liste_knn.append(knn)

# %% [markdown]
# ### Avec Word2Vec

# %%
# liste de tuples nommés Classifieur(pipeline, param_grid)
pipeline_knn = Pipeline([
        ('ngram_tf_idf', Pipeline([
          ('counts', FunctionTransformer(w2vVectorizer)),
          ('tf_idf', TfidfTransformer())
        ])),
  #('standard', StandardScaler(with_mean=False)),
    ('select',SelectKBest()),
  ('knn', KNeighborsClassifier())])

param_grid_knn = {
    #"ngram_tf_idf__counts__stop_words":('french',None), #TODO: pas de french : utiliser la liste de spacy ou nltk
    "ngram_tf_idf__tf_idf__use_idf":(True,False),
   # "ngram_tf_idf__tf_idf__sublinear_tf":(True,False),
    "knn__algorithm":('auto', 'brute'),
    "select__k":(10,50,100,200),
    "knn__n_neighbors":(2,5)
    }

knn = Classifieur(pipeline_knn, param_grid_knn)
liste_knn.append(knn)

# %% [markdown]
# ### TEST

# %%
best_models_knn = []

for (pipeline, param_grid) in liste_knn:
    print("="*80)
    grid_search = GridSearchCV(pipeline, param_grid=param_grid,verbose=10)
    estimator = grid_search.fit(X_train_clean, y_train_bin)
    best_models_knn.append(estimator)
    print("="*80,'\n')
# Out:
# ================================================================================
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV 1/5; 1/24] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=10
# [CV 1/5; 1/24] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=10;, score=0.273 total time=  17.3s
# [CV 2/5; 1/24] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=10
# [CV 2/5; 1/24] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=10;, score=0.284 total time=  17.8s
# [CV 3/5; 1/24] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=10
# [CV 3/5; 1/24] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=10;, score=0.297 total time=  17.9s
# [CV 4/5; 1/24] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=10
# [CV 4/5; 1/24] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=10;, score=0.286 total time=  17.1s
# [CV 5/5; 1/24] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=10
# [CV 5/5; 1/24] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=10;, score=0.288 total time=  17.0s
# [CV 1/5; 2/24] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=20
# [CV 1/5; 2/24] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=20;, score=0.302 total time=  19.0s
# [CV 2/5; 2/24] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=20
# [CV 2/5; 2/24] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=20;, score=0.296 total time=  18.9s
# [CV 3/5; 2/24] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=20
# [CV 3/5; 2/24] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=20;, score=0.313 total time=  20.4s
# [CV 4/5; 2/24] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=20
# [CV 4/5; 2/24] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=20;, score=0.305 total time=  18.7s
# [CV 5/5; 2/24] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=20
# [CV 5/5; 2/24] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=20;, score=0.295 total time=  18.7s
# [CV 1/5; 3/24] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=50
# [CV 1/5; 3/24] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=50;, score=0.314 total time=  24.7s
# [CV 2/5; 3/24] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=50
# [CV 2/5; 3/24] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=50;, score=0.317 total time=  28.4s
# [CV 3/5; 3/24] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=50
# [CV 3/5; 3/24] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=50;, score=0.327 total time=  42.7s
# [CV 4/5; 3/24] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=50
# [CV 4/5; 3/24] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=50;, score=0.316 total time=  27.2s
# [CV 5/5; 3/24] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=50
# [CV 5/5; 3/24] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=50;, score=0.321 total time=  24.7s
# [CV 1/5; 4/24] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=10
# [CV 1/5; 4/24] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=10;, score=0.273 total time=  18.9s
# [CV 2/5; 4/24] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=10
# [CV 2/5; 4/24] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=10;, score=0.284 total time=  17.2s
# [CV 3/5; 4/24] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=10
# [CV 3/5; 4/24] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=10;, score=0.297 total time=  17.2s
# [CV 4/5; 4/24] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=10
# [CV 4/5; 4/24] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=10;, score=0.286 total time=  16.8s
# [CV 5/5; 4/24] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=10
# [CV 5/5; 4/24] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=10;, score=0.288 total time=  17.1s
# [CV 1/5; 5/24] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=20
# [CV 1/5; 5/24] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=20;, score=0.302 total time=  19.1s
# [CV 2/5; 5/24] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=20
# [CV 2/5; 5/24] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=20;, score=0.296 total time=  19.8s
# [CV 3/5; 5/24] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=20
# [CV 3/5; 5/24] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=20;, score=0.313 total time=  20.8s
# [CV 4/5; 5/24] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=20
# [CV 4/5; 5/24] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=20;, score=0.305 total time=  18.9s
# [CV 5/5; 5/24] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=20
# [CV 5/5; 5/24] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=20;, score=0.295 total time=  18.7s
# [CV 1/5; 6/24] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=50
# [CV 1/5; 6/24] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=50;, score=0.314 total time=  24.6s
# [CV 2/5; 6/24] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=50
# [CV 2/5; 6/24] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=50;, score=0.317 total time=  28.1s
# [CV 3/5; 6/24] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=50
# [CV 3/5; 6/24] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=50;, score=0.327 total time=  24.8s
# [CV 4/5; 6/24] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=50
# [CV 4/5; 6/24] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=50;, score=0.316 total time=  24.9s
# [CV 5/5; 6/24] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=50
# [CV 5/5; 6/24] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=50;, score=0.321 total time=  26.6s
# [CV 1/5; 7/24] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=10
# [CV 1/5; 7/24] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=10;, score=0.315 total time=  17.6s
# [CV 2/5; 7/24] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=10
# [CV 2/5; 7/24] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=10;, score=0.321 total time=  17.3s
# [CV 3/5; 7/24] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=10
# [CV 3/5; 7/24] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=10;, score=0.326 total time=  17.4s
# [CV 4/5; 7/24] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=10
# [CV 4/5; 7/24] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=10;, score=0.313 total time=  17.3s
# [CV 5/5; 7/24] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=10
# [CV 5/5; 7/24] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=10;, score=0.320 total time=  17.5s
# [CV 1/5; 8/24] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=20
# [CV 1/5; 8/24] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=20;, score=0.335 total time=  19.8s
# [CV 2/5; 8/24] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=20
# [CV 2/5; 8/24] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=20;, score=0.326 total time=  19.0s
# [CV 3/5; 8/24] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=20
# [CV 3/5; 8/24] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=20;, score=0.343 total time=  20.4s
# [CV 4/5; 8/24] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=20
# [CV 4/5; 8/24] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=20;, score=0.329 total time=  19.1s
# [CV 5/5; 8/24] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=20
# [CV 5/5; 8/24] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=20;, score=0.327 total time=  20.3s
# [CV 1/5; 9/24] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=50
# [CV 1/5; 9/24] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=50;, score=0.340 total time=  25.9s
# [CV 2/5; 9/24] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=50
# [CV 2/5; 9/24] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=50;, score=0.341 total time=  25.1s
# [CV 3/5; 9/24] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=50
# [CV 3/5; 9/24] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=50;, score=0.351 total time=  25.2s
# [CV 4/5; 9/24] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=50
# [CV 4/5; 9/24] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=50;, score=0.353 total time=  25.2s
# [CV 5/5; 9/24] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=50
# [CV 5/5; 9/24] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=50;, score=0.347 total time=  26.6s
# [CV 1/5; 10/24] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=10
# [CV 1/5; 10/24] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=10;, score=0.315 total time=  17.4s
# [CV 2/5; 10/24] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=10
# [CV 2/5; 10/24] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=10;, score=0.321 total time=  17.2s
# [CV 3/5; 10/24] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=10
# [CV 3/5; 10/24] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=10;, score=0.326 total time=  17.1s
# [CV 4/5; 10/24] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=10
# [CV 4/5; 10/24] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=10;, score=0.313 total time=  17.1s
# [CV 5/5; 10/24] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=10
# [CV 5/5; 10/24] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=10;, score=0.320 total time=  17.5s
# [CV 1/5; 11/24] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=20
# [CV 1/5; 11/24] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=20;, score=0.335 total time=  19.6s
# [CV 2/5; 11/24] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=20
# [CV 2/5; 11/24] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=20;, score=0.326 total time=  18.9s
# [CV 3/5; 11/24] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=20
# [CV 3/5; 11/24] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=20;, score=0.343 total time=  19.2s
# [CV 4/5; 11/24] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=20
# [CV 4/5; 11/24] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=20;, score=0.329 total time=  20.8s
# [CV 5/5; 11/24] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=20
# [CV 5/5; 11/24] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=20;, score=0.327 total time=  19.5s
# [CV 1/5; 12/24] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=50
# [CV 1/5; 12/24] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=50;, score=0.340 total time=  25.1s
# [CV 2/5; 12/24] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=50
# [CV 2/5; 12/24] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=50;, score=0.341 total time=  25.7s
# [CV 3/5; 12/24] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=50
# [CV 3/5; 12/24] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=50;, score=0.351 total time=  25.1s
# [CV 4/5; 12/24] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=50
# [CV 4/5; 12/24] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=50;, score=0.353 total time=  24.8s
# [CV 5/5; 12/24] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=50
# [CV 5/5; 12/24] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=50;, score=0.347 total time=  26.7s
# [CV 1/5; 13/24] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=10
# [CV 1/5; 13/24] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=10;, score=0.273 total time=  16.9s
# [CV 2/5; 13/24] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=10
# [CV 2/5; 13/24] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=10;, score=0.284 total time=  17.0s
# [CV 3/5; 13/24] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=10
# [CV 3/5; 13/24] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=10;, score=0.297 total time=  17.2s
# [CV 4/5; 13/24] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=10
# [CV 4/5; 13/24] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=10;, score=0.286 total time=  17.3s
# [CV 5/5; 13/24] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=10
# [CV 5/5; 13/24] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=10;, score=0.288 total time=  17.4s
# [CV 1/5; 14/24] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=20
# [CV 1/5; 14/24] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=20;, score=0.302 total time=  18.6s
# [CV 2/5; 14/24] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=20
# [CV 2/5; 14/24] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=20;, score=0.296 total time=  18.8s
# [CV 3/5; 14/24] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=20
# [CV 3/5; 14/24] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=20;, score=0.313 total time=  18.9s
# [CV 4/5; 14/24] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=20
# [CV 4/5; 14/24] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=20;, score=0.305 total time=  20.5s
# [CV 5/5; 14/24] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=20
# [CV 5/5; 14/24] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=20;, score=0.295 total time=  18.5s
# [CV 1/5; 15/24] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=50
# [CV 1/5; 15/24] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=50;, score=0.314 total time=  24.5s
# [CV 2/5; 15/24] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=50
# [CV 2/5; 15/24] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=50;, score=0.317 total time=  24.6s
# [CV 3/5; 15/24] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=50
# [CV 3/5; 15/24] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=50;, score=0.327 total time=  24.5s
# [CV 4/5; 15/24] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=50
# [CV 4/5; 15/24] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=50;, score=0.316 total time=  24.6s
# [CV 5/5; 15/24] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=50
# [CV 5/5; 15/24] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=50;, score=0.321 total time=  25.2s
# [CV 1/5; 16/24] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=10
# [CV 1/5; 16/24] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=10;, score=0.273 total time=  18.9s
# [CV 2/5; 16/24] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=10
# [CV 2/5; 16/24] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=10;, score=0.284 total time=  16.8s
# [CV 3/5; 16/24] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=10
# [CV 3/5; 16/24] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=10;, score=0.297 total time=  17.0s
# [CV 4/5; 16/24] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=10
# [CV 4/5; 16/24] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=10;, score=0.286 total time=  17.0s
# [CV 5/5; 16/24] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=10
# [CV 5/5; 16/24] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=10;, score=0.288 total time=  16.9s
# [CV 1/5; 17/24] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=20
# [CV 1/5; 17/24] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=20;, score=0.302 total time=  18.7s
# [CV 2/5; 17/24] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=20
# [CV 2/5; 17/24] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=20;, score=0.296 total time=  19.9s
# [CV 3/5; 17/24] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=20
# [CV 3/5; 17/24] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=20;, score=0.313 total time=  19.3s
# [CV 4/5; 17/24] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=20
# [CV 4/5; 17/24] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=20;, score=0.305 total time=  18.5s
# [CV 5/5; 17/24] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=20
# [CV 5/5; 17/24] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=20;, score=0.295 total time=  20.6s
# [CV 1/5; 18/24] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=50
# [CV 1/5; 18/24] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=50;, score=0.314 total time=  24.7s
# [CV 2/5; 18/24] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=50
# [CV 2/5; 18/24] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=50;, score=0.317 total time=  25.9s
# [CV 3/5; 18/24] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=50
# [CV 3/5; 18/24] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=50;, score=0.327 total time=  24.5s
# [CV 4/5; 18/24] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=50
# [CV 4/5; 18/24] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=50;, score=0.316 total time=  24.6s
# [CV 5/5; 18/24] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=50
# [CV 5/5; 18/24] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=50;, score=0.321 total time=  24.3s
# [CV 1/5; 19/24] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=10
# [CV 1/5; 19/24] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=10;, score=0.315 total time=  17.6s
# [CV 2/5; 19/24] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=10
# [CV 2/5; 19/24] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=10;, score=0.321 total time=  18.1s
# [CV 3/5; 19/24] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=10
# [CV 3/5; 19/24] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=10;, score=0.326 total time=  17.4s
# [CV 4/5; 19/24] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=10
# [CV 4/5; 19/24] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=10;, score=0.313 total time=  17.4s
# [CV 5/5; 19/24] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=10
# [CV 5/5; 19/24] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=10;, score=0.320 total time=  17.5s
# [CV 1/5; 20/24] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=20
# [CV 1/5; 20/24] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=20;, score=0.335 total time=  19.6s
# [CV 2/5; 20/24] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=20
# [CV 2/5; 20/24] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=20;, score=0.326 total time=  19.5s
# [CV 3/5; 20/24] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=20
# [CV 3/5; 20/24] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=20;, score=0.343 total time=  18.9s
# [CV 4/5; 20/24] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=20
# [CV 4/5; 20/24] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=20;, score=0.329 total time=  18.9s
# [CV 5/5; 20/24] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=20
# [CV 5/5; 20/24] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=20;, score=0.327 total time=  21.8s
# [CV 1/5; 21/24] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=50
# [CV 1/5; 21/24] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=50;, score=0.340 total time=  25.4s
# [CV 2/5; 21/24] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=50
# [CV 2/5; 21/24] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=50;, score=0.341 total time=  25.1s
# [CV 3/5; 21/24] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=50
# [CV 3/5; 21/24] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=50;, score=0.351 total time=  25.0s
# [CV 4/5; 21/24] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=50
# [CV 4/5; 21/24] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=50;, score=0.353 total time=  24.9s
# [CV 5/5; 21/24] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=50
# [CV 5/5; 21/24] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=50;, score=0.347 total time=  26.7s
# [CV 1/5; 22/24] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=10
# [CV 1/5; 22/24] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=10;, score=0.315 total time=  19.8s
# [CV 2/5; 22/24] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=10
# [CV 2/5; 22/24] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=10;, score=0.321 total time=  17.4s
# [CV 3/5; 22/24] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=10
# [CV 3/5; 22/24] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=10;, score=0.326 total time=  17.0s
# [CV 4/5; 22/24] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=10
# [CV 4/5; 22/24] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=10;, score=0.313 total time=  17.2s
# [CV 5/5; 22/24] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=10
# [CV 5/5; 22/24] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=10;, score=0.320 total time=  17.3s
# [CV 1/5; 23/24] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=20
# [CV 1/5; 23/24] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=20;, score=0.335 total time=  19.2s
# [CV 2/5; 23/24] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=20
# [CV 2/5; 23/24] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=20;, score=0.326 total time=  19.0s
# [CV 3/5; 23/24] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=20
# [CV 3/5; 23/24] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=20;, score=0.343 total time=  18.7s
# [CV 4/5; 23/24] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=20
# [CV 4/5; 23/24] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=20;, score=0.329 total time=  19.1s
# [CV 5/5; 23/24] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=20
# [CV 5/5; 23/24] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=20;, score=0.327 total time=  21.9s
# [CV 1/5; 24/24] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=50
# [CV 1/5; 24/24] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=50;, score=0.340 total time=  25.1s
# [CV 2/5; 24/24] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=50
# [CV 2/5; 24/24] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=50;, score=0.341 total time=  25.3s
# [CV 3/5; 24/24] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=50
# [CV 3/5; 24/24] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=50;, score=0.351 total time=  24.8s
# [CV 4/5; 24/24] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=50
# [CV 4/5; 24/24] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=50;, score=0.353 total time=  24.7s
# [CV 5/5; 24/24] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=50
# [CV 5/5; 24/24] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=50;, score=0.347 total time=  25.2s
# ================================================================================
#
# ================================================================================
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# [CV 1/5; 1/32] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=10
# [CV 1/5; 1/32] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=10;, score=0.300 total time=  21.2s
# [CV 2/5; 1/32] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=10
# [CV 2/5; 1/32] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=10;, score=0.305 total time=  21.0s
# [CV 3/5; 1/32] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=10
# [CV 3/5; 1/32] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=10;, score=0.297 total time=  20.9s
# [CV 4/5; 1/32] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=10
# [CV 4/5; 1/32] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=10;, score=0.312 total time=  21.0s
# [CV 5/5; 1/32] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=10
# [CV 5/5; 1/32] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=10;, score=0.302 total time=  21.2s
# [CV 1/5; 2/32] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=50
# [CV 1/5; 2/32] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=50;, score=0.345 total time=  28.5s
# [CV 2/5; 2/32] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=50
# [CV 2/5; 2/32] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=50;, score=0.341 total time=  30.3s
# [CV 3/5; 2/32] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=50
# [CV 3/5; 2/32] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=50;, score=0.351 total time=  28.5s
# [CV 4/5; 2/32] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=50
# [CV 4/5; 2/32] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=50;, score=0.342 total time=  28.6s
# [CV 5/5; 2/32] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=50
# [CV 5/5; 2/32] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=50;, score=0.352 total time=  28.7s
# [CV 1/5; 3/32] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=100
# [CV 1/5; 3/32] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=100;, score=0.355 total time=  38.6s
# [CV 2/5; 3/32] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=100
# [CV 2/5; 3/32] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=100;, score=0.354 total time=  40.4s
# [CV 3/5; 3/32] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=100
# [CV 3/5; 3/32] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=100;, score=0.360 total time=  39.5s
# [CV 4/5; 3/32] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=100
# [CV 4/5; 3/32] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=100;, score=0.347 total time=  39.5s
# [CV 5/5; 3/32] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=100
# [CV 5/5; 3/32] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=100;, score=0.356 total time=  42.1s
# [CV 1/5; 4/32] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=200
# [CV 1/5; 4/32] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=200;, score=0.360 total time= 1.1min
# [CV 2/5; 4/32] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=200
# [CV 2/5; 4/32] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=200;, score=0.358 total time= 1.0min
# [CV 3/5; 4/32] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=200
# [CV 3/5; 4/32] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=200;, score=0.353 total time= 1.0min
# [CV 4/5; 4/32] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=200
# [CV 4/5; 4/32] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=200;, score=0.361 total time=  59.7s
# [CV 5/5; 4/32] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=200
# [CV 5/5; 4/32] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=200;, score=0.363 total time=  59.5s
# [CV 1/5; 5/32] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=10
# [CV 1/5; 5/32] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=10;, score=0.300 total time=  23.1s
# [CV 2/5; 5/32] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=10
# [CV 2/5; 5/32] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=10;, score=0.305 total time=  21.3s
# [CV 3/5; 5/32] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=10
# [CV 3/5; 5/32] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=10;, score=0.297 total time=  22.5s
# [CV 4/5; 5/32] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=10
# [CV 4/5; 5/32] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=10;, score=0.312 total time=  21.6s
# [CV 5/5; 5/32] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=10
# [CV 5/5; 5/32] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=10;, score=0.302 total time=  21.4s
# [CV 1/5; 6/32] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=50
# [CV 1/5; 6/32] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=50;, score=0.345 total time=  29.0s
# [CV 2/5; 6/32] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=50
# [CV 2/5; 6/32] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=50;, score=0.341 total time=  29.5s
# [CV 3/5; 6/32] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=50
# [CV 3/5; 6/32] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=50;, score=0.351 total time=  29.1s
# [CV 4/5; 6/32] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=50
# [CV 4/5; 6/32] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=50;, score=0.342 total time=  30.0s
# [CV 5/5; 6/32] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=50
# [CV 5/5; 6/32] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=50;, score=0.352 total time=  29.9s
# [CV 1/5; 7/32] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=100
# [CV 1/5; 7/32] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=100;, score=0.355 total time=  39.5s
# [CV 2/5; 7/32] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=100
# [CV 2/5; 7/32] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=100;, score=0.354 total time=  40.8s
# [CV 3/5; 7/32] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=100
# [CV 3/5; 7/32] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=100;, score=0.360 total time=  38.6s
# [CV 4/5; 7/32] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=100
# [CV 4/5; 7/32] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=100;, score=0.347 total time=  39.0s
# [CV 5/5; 7/32] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=100
# [CV 5/5; 7/32] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=100;, score=0.356 total time=  39.0s
# [CV 1/5; 8/32] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=200
# [CV 1/5; 8/32] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=200;, score=0.360 total time= 1.0min
# [CV 2/5; 8/32] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=200
# [CV 2/5; 8/32] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=200;, score=0.358 total time=  59.6s
# [CV 3/5; 8/32] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=200
# [CV 3/5; 8/32] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=200;, score=0.353 total time= 1.0min
# [CV 4/5; 8/32] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=200
# [CV 4/5; 8/32] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=200;, score=0.361 total time=  59.8s
# [CV 5/5; 8/32] START knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=200
# [CV 5/5; 8/32] END knn__algorithm=auto, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=200;, score=0.363 total time=  59.3s
# [CV 1/5; 9/32] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=10
# [CV 1/5; 9/32] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=10;, score=0.338 total time=  23.9s
# [CV 2/5; 9/32] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=10
# [CV 2/5; 9/32] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=10;, score=0.334 total time=  21.9s
# [CV 3/5; 9/32] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=10
# [CV 3/5; 9/32] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=10;, score=0.328 total time=  21.9s
# [CV 4/5; 9/32] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=10
# [CV 4/5; 9/32] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=10;, score=0.341 total time=  22.0s
# [CV 5/5; 9/32] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=10
# [CV 5/5; 9/32] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=10;, score=0.334 total time=  22.7s
# [CV 1/5; 10/32] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=50
# [CV 1/5; 10/32] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=50;, score=0.386 total time=  29.6s
# [CV 2/5; 10/32] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=50
# [CV 2/5; 10/32] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=50;, score=0.372 total time=  32.7s
# [CV 3/5; 10/32] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=50
# [CV 3/5; 10/32] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=50;, score=0.384 total time=  30.1s
# [CV 4/5; 10/32] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=50
# [CV 4/5; 10/32] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=50;, score=0.367 total time=  29.6s
# [CV 5/5; 10/32] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=50
# [CV 5/5; 10/32] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=50;, score=0.380 total time=  29.9s
# [CV 1/5; 11/32] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=100
# [CV 1/5; 11/32] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=100;, score=0.396 total time=  41.2s
# [CV 2/5; 11/32] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=100
# [CV 2/5; 11/32] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=100;, score=0.389 total time=  40.1s
# [CV 3/5; 11/32] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=100
# [CV 3/5; 11/32] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=100;, score=0.398 total time=  39.7s
# [CV 4/5; 11/32] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=100
# [CV 4/5; 11/32] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=100;, score=0.380 total time=  40.5s
# [CV 5/5; 11/32] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=100
# [CV 5/5; 11/32] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=100;, score=0.389 total time=  41.7s
# [CV 1/5; 12/32] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=200
# [CV 1/5; 12/32] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=200;, score=0.400 total time= 1.0min
# [CV 2/5; 12/32] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=200
# [CV 2/5; 12/32] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=200;, score=0.403 total time=  59.7s
# [CV 3/5; 12/32] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=200
# [CV 3/5; 12/32] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=200;, score=0.393 total time= 1.0min
# [CV 4/5; 12/32] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=200
# [CV 4/5; 12/32] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=200;, score=0.392 total time= 1.0min
# [CV 5/5; 12/32] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=200
# [CV 5/5; 12/32] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=200;, score=0.396 total time= 1.1min
# [CV 1/5; 13/32] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=10
# [CV 1/5; 13/32] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=10;, score=0.338 total time=  25.6s
# [CV 2/5; 13/32] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=10
# [CV 2/5; 13/32] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=10;, score=0.334 total time=  25.0s
# [CV 3/5; 13/32] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=10
# [CV 3/5; 13/32] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=10;, score=0.328 total time=  25.7s
# [CV 4/5; 13/32] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=10
# [CV 4/5; 13/32] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=10;, score=0.341 total time=  25.6s
# [CV 5/5; 13/32] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=10
# [CV 5/5; 13/32] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=10;, score=0.334 total time=  26.8s
# [CV 1/5; 14/32] START knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=50
# [CV 1/5; 14/32] END knn__algorithm=auto, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=50;, score=0.386 total time=  33.9s
# ...
# [CV 5/5; 20/32] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=200
# [CV 5/5; 20/32] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=True, select__k=200;, score=0.363 total time= 1.1min
# [CV 1/5; 21/32] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=10
# [CV 1/5; 21/32] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=10;, score=0.300 total time=  25.2s
# [CV 2/5; 21/32] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=10
# [CV 2/5; 21/32] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=10;, score=0.305 total time=  23.4s
# [CV 3/5; 21/32] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=10
# [CV 3/5; 21/32] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=10;, score=0.297 total time=  23.9s
# [CV 4/5; 21/32] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=10
# [CV 4/5; 21/32] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=10;, score=0.312 total time=  23.7s
# [CV 5/5; 21/32] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=10
# [CV 5/5; 21/32] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=10;, score=0.302 total time=  24.4s
# [CV 1/5; 22/32] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=50
# [CV 1/5; 22/32] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=50;, score=0.345 total time=  31.3s
# [CV 2/5; 22/32] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=50
# [CV 2/5; 22/32] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=50;, score=0.341 total time=  30.9s
# [CV 3/5; 22/32] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=50
# [CV 3/5; 22/32] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=50;, score=0.351 total time=  30.8s
# [CV 4/5; 22/32] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=50
# [CV 4/5; 22/32] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=50;, score=0.342 total time=  33.0s
# [CV 5/5; 22/32] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=50
# [CV 5/5; 22/32] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=50;, score=0.352 total time=  29.2s
# [CV 1/5; 23/32] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=100
# [CV 1/5; 23/32] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=100;, score=0.355 total time=  39.3s
# [CV 2/5; 23/32] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=100
# [CV 2/5; 23/32] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=100;, score=0.354 total time=  39.1s
# [CV 3/5; 23/32] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=100
# [CV 3/5; 23/32] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=100;, score=0.360 total time=  38.8s
# [CV 4/5; 23/32] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=100
# [CV 4/5; 23/32] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=100;, score=0.347 total time=  39.2s
# [CV 5/5; 23/32] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=100
# [CV 5/5; 23/32] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=100;, score=0.356 total time=  45.1s
# [CV 1/5; 24/32] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=200
# [CV 1/5; 24/32] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=200;, score=0.360 total time=  58.0s
# [CV 2/5; 24/32] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=200
# [CV 2/5; 24/32] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=200;, score=0.358 total time=  58.0s
# [CV 3/5; 24/32] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=200
# [CV 3/5; 24/32] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=200;, score=0.353 total time= 1.0min
# [CV 4/5; 24/32] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=200
# [CV 4/5; 24/32] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=200;, score=0.361 total time=  58.6s
# [CV 5/5; 24/32] START knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=200
# [CV 5/5; 24/32] END knn__algorithm=brute, knn__n_neighbors=2, ngram_tf_idf__tf_idf__use_idf=False, select__k=200;, score=0.363 total time=  58.6s
# [CV 1/5; 25/32] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=10
# [CV 1/5; 25/32] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=10;, score=0.338 total time=  21.4s
# [CV 2/5; 25/32] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=10
# [CV 2/5; 25/32] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=10;, score=0.334 total time=  21.5s
# [CV 3/5; 25/32] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=10
# [CV 3/5; 25/32] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=10;, score=0.328 total time=  21.8s
# [CV 4/5; 25/32] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=10
# [CV 4/5; 25/32] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=10;, score=0.341 total time=  26.5s
# [CV 5/5; 25/32] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=10
# [CV 5/5; 25/32] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=10;, score=0.334 total time=  21.6s
# [CV 1/5; 26/32] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=50
# [CV 1/5; 26/32] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=50;, score=0.386 total time=  29.7s
# [CV 2/5; 26/32] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=50
# [CV 2/5; 26/32] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=50;, score=0.372 total time=  29.9s
# [CV 3/5; 26/32] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=50
# [CV 3/5; 26/32] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=50;, score=0.384 total time=  29.2s
# [CV 4/5; 26/32] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=50
# [CV 4/5; 26/32] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=50;, score=0.367 total time=  29.1s
# [CV 5/5; 26/32] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=50
# [CV 5/5; 26/32] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=50;, score=0.380 total time=  28.9s
# [CV 1/5; 27/32] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=100
# [CV 1/5; 27/32] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=100;, score=0.396 total time=  41.2s
# [CV 2/5; 27/32] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=100
# [CV 2/5; 27/32] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=100;, score=0.389 total time=  38.6s
# [CV 3/5; 27/32] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=100
# [CV 3/5; 27/32] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=100;, score=0.398 total time=  38.6s
# [CV 4/5; 27/32] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=100
# [CV 4/5; 27/32] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=100;, score=0.380 total time=  39.1s
# [CV 5/5; 27/32] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=100
# [CV 5/5; 27/32] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=100;, score=0.389 total time=  39.0s
# [CV 1/5; 28/32] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=200
# [CV 1/5; 28/32] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=200;, score=0.400 total time= 1.0min
# [CV 2/5; 28/32] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=200
# [CV 2/5; 28/32] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=200;, score=0.403 total time=  58.2s
# [CV 3/5; 28/32] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=200
# [CV 3/5; 28/32] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=200;, score=0.393 total time=  58.2s
# [CV 4/5; 28/32] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=200
# [CV 4/5; 28/32] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=200;, score=0.392 total time= 1.0min
# [CV 5/5; 28/32] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=200
# [CV 5/5; 28/32] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=True, select__k=200;, score=0.396 total time=  58.3s
# [CV 1/5; 29/32] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=10
# [CV 1/5; 29/32] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=10;, score=0.338 total time=  21.0s
# [CV 2/5; 29/32] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=10
# [CV 2/5; 29/32] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=10;, score=0.334 total time=  20.9s
# [CV 3/5; 29/32] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=10
# [CV 3/5; 29/32] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=10;, score=0.328 total time=  21.0s
# [CV 4/5; 29/32] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=10
# [CV 4/5; 29/32] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=10;, score=0.341 total time=  21.2s
# [CV 5/5; 29/32] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=10
# [CV 5/5; 29/32] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=10;, score=0.334 total time=  21.2s
# [CV 1/5; 30/32] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=50
# [CV 1/5; 30/32] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=50;, score=0.386 total time=  31.8s
# [CV 2/5; 30/32] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=50
# [CV 2/5; 30/32] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=50;, score=0.372 total time=  28.7s
# [CV 3/5; 30/32] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=50
# [CV 3/5; 30/32] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=50;, score=0.384 total time=  28.7s
# [CV 4/5; 30/32] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=50
# [CV 4/5; 30/32] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=50;, score=0.367 total time=  28.9s
# [CV 5/5; 30/32] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=50
# [CV 5/5; 30/32] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=50;, score=0.380 total time=  28.8s
# [CV 1/5; 31/32] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=100
# [CV 1/5; 31/32] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=100;, score=0.396 total time=  38.3s
# [CV 2/5; 31/32] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=100
# [CV 2/5; 31/32] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=100;, score=0.389 total time=  38.6s
# [CV 3/5; 31/32] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=100
# [CV 3/5; 31/32] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=100;, score=0.398 total time=  42.4s
# [CV 4/5; 31/32] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=100
# [CV 4/5; 31/32] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=100;, score=0.380 total time=  38.5s
# [CV 5/5; 31/32] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=100
# [CV 5/5; 31/32] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=100;, score=0.389 total time=  38.6s
# [CV 1/5; 32/32] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=200
# [CV 1/5; 32/32] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=200;, score=0.400 total time=  58.3s
# [CV 2/5; 32/32] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=200
# [CV 2/5; 32/32] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=200;, score=0.403 total time= 1.0min
# [CV 3/5; 32/32] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=200
# [CV 3/5; 32/32] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=200;, score=0.393 total time=  58.9s
# [CV 4/5; 32/32] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=200
# [CV 4/5; 32/32] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=200;, score=0.392 total time=  58.7s
# [CV 5/5; 32/32] START knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=200
# [CV 5/5; 32/32] END knn__algorithm=brute, knn__n_neighbors=5, ngram_tf_idf__tf_idf__use_idf=False, select__k=200;, score=0.396 total time= 1.0min
# ================================================================================

# %%
for m in best_models_knn:
  y_pred = m.predict(X_test_clean)
  print(classification_report(y_test_bin, y_pred))
  print("="*80)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.36      0.26      0.30      1339
#            1       0.53      0.44      0.48      1793
#            2       0.47      0.69      0.56      4571
#            3       0.46      0.43      0.44      3629
#            4       0.41      0.12      0.18      1585
#
#     accuracy                           0.47     12917
#    macro avg       0.45      0.39      0.39     12917
# weighted avg       0.46      0.47      0.44     12917
#
# ================================================================================
#               precision    recall  f1-score   support
#
#            0       0.43      0.31      0.36      1339
#            1       0.58      0.55      0.56      1793
#            2       0.52      0.72      0.60      4571
#            3       0.51      0.48      0.49      3629
#            4       0.52      0.15      0.23      1585
#
#     accuracy                           0.52     12917
#    macro avg       0.51      0.44      0.45     12917
# weighted avg       0.51      0.52      0.50     12917
#
# ================================================================================

# %%
for clf, estimator in zip(['glove','word2vec'],best_models_knn):
  pd_estimator = pd.DataFrame.from_dict(estimator.cv_results_)
  pd_estimator = pd_estimator.sort_values(by="rank_test_score", ascending=True)
  pd_estimator.to_csv(f"{clf}_cvresults_all_knn.csv")

# %% [markdown]
# ## `Régression Logistique`

# %%
from sklearn.impute import SimpleImputer

# %%
from sklearn.linear_model import LogisticRegression

# %%
liste_reglog = []

# %% [markdown]
# ### Avec CountVectorizer

# %%
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.multiclass import OneVsOneClassifier
from sklearn.preprocessing import LabelBinarizer 

# liste de tuples nommés Classifieur(pipeline, param_grid)
pipeline_reglog = Pipeline([
        ('ngram_tf_idf', Pipeline([
          ('counts', CountVectorizer(min_df=1)),
          ('tf_idf', TfidfTransformer())
        ])),
  ('standard', StandardScaler(with_mean=False)),
  ('rl', OneVsOneClassifier(LogisticRegression(max_iter=10000,multi_class='ovr',solver='liblinear')))])

param_grid_reglog = {
    #"ngram_tf_idf__counts__ngram_range": ((1, 1),(2,2)),  # unigrams or bigrams
    #"ngram_tf_idf__counts__stop_words":('french',None), #TODO: pas de french : utiliser la liste de spacy ou nltk
    "ngram_tf_idf__tf_idf__use_idf":(True,False),
    #"ngram_tf_idf__tf_idf__sublinear_tf":(True,False),
    #"rl__class_weight":('balanced',None),
    #"rl__penalty": ('l1','l2'),
    #"rl__solver":('newton-cg', 'newton-cholesky', 'sag', 'saga'),
    #"rl__C":(0.1,0.5,1.0,1.5) # complexité du modèle
    }

# Créer un objet LabelBinarizer
lb = LabelBinarizer()
y_test_bin = lb.fit_transform(y_test)

pipeline_reglog.fit(X_train_clean, y_train_bin)
y_pred = pipeline_reglog.predict(X_test_clean)
print(pipeline_reglog.score(X_test_clean,y_test_bin))
print(pipeline_reglog.score(X_train_clean,y_train_bin))


# Convertir les étiquettes de classe en un tableau binaire
y_pred_bin = lb.fit_transform(y_pred)

print(classification_report(y_test, y_pred_bin.classes_))

reglog = Classifieur(pipeline_reglog, param_grid_reglog)
liste_reglog.append(reglog)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-66-e1461d5cd51e> in <module>
#      27 y_test_bin = lb.fit_transform(y_test)
#      28
# ---> 29 pipeline_reglog.fit(X_train_clean, y_train_bin)
#      30 y_pred = pipeline_reglog.predict(X_test_clean)
#      31 print(pipeline_reglog.score(X_test_clean,y_test_bin))
#
# /usr/local/lib/python3.8/dist-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     388         """
#     389         fit_params_steps = self._check_fit_params(**fit_params)
# --> 390         Xt = self._fit(X, y, **fit_params_steps)
#     391         with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#     392             if self._final_estimator != "passthrough":
#
# /usr/local/lib/python3.8/dist-packages/sklearn/pipeline.py in _fit(self, X, y, **fit_params_steps)
#     346                 cloned_transformer = clone(transformer)
#     347             # Fit or load from cache the current transformer
# --> 348             X, fitted_transformer = fit_transform_one_cached(
#     349                 cloned_transformer,
#     350                 X,
#
# /usr/local/lib/python3.8/dist-packages/joblib/memory.py in __call__(self, *args, **kwargs)
#     347
#     348     def __call__(self, *args, **kwargs):
# --> 349         return self.func(*args, **kwargs)
#     350
#     351     def call_and_shelve(self, *args, **kwargs):
#
# /usr/local/lib/python3.8/dist-packages/sklearn/pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     891     with _print_elapsed_time(message_clsname, message):
#     892         if hasattr(transformer, "fit_transform"):
# --> 893             res = transformer.fit_transform(X, y, **fit_params)
#     894         else:
#     895             res = transformer.fit(X, y, **fit_params).transform(X)
#
# /usr/local/lib/python3.8/dist-packages/sklearn/pipeline.py in fit_transform(self, X, y, **fit_params)
#     424         """
#     425         fit_params_steps = self._check_fit_params(**fit_params)
# --> 426         Xt = self._fit(X, y, **fit_params_steps)
#     427
#     428         last_step = self._final_estimator
#
# /usr/local/lib/python3.8/dist-packages/sklearn/pipeline.py in _fit(self, X, y, **fit_params_steps)
#     346                 cloned_transformer = clone(transformer)
#     347             # Fit or load from cache the current transformer
# --> 348             X, fitted_transformer = fit_transform_one_cached(
#     349                 cloned_transformer,
#     350                 X,
#
# /usr/local/lib/python3.8/dist-packages/joblib/memory.py in __call__(self, *args, **kwargs)
#     347
#     348     def __call__(self, *args, **kwargs):
# --> 349         return self.func(*args, **kwargs)
#     350
#     351     def call_and_shelve(self, *args, **kwargs):
#
# /usr/local/lib/python3.8/dist-packages/sklearn/pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     891     with _print_elapsed_time(message_clsname, message):
#     892         if hasattr(transformer, "fit_transform"):
# --> 893             res = transformer.fit_transform(X, y, **fit_params)
#     894         else:
#     895             res = transformer.fit(X, y, **fit_params).transform(X)
#
# /usr/local/lib/python3.8/dist-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1328                     break
#    1329
# -> 1330         vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1331
#    1332         if self.binary:
#
# /usr/local/lib/python3.8/dist-packages/sklearn/feature_extraction/text.py in _count_vocab(self, raw_documents, fixed_vocab)
#    1235         else:
#    1236             indices_dtype = np.int32
# -> 1237         j_indices = np.asarray(j_indices, dtype=indices_dtype)
#    1238         indptr = np.asarray(indptr, dtype=indices_dtype)
#    1239         values = np.frombuffer(values, dtype=np.intc)
#
# KeyboardInterrupt:

# %%
print(pipeline_reglog.score(X_test_clean,y_test_bin.cl))

# %% [markdown]
# ### Avec GloveVectorizer()

# %%
# liste de tuples nommés Classifieur(pipeline, param_grid)
from sklearn.preprocessing import MinMaxScaler
pipeline_reglog = Pipeline([
        ('ngram_tf_idf', Pipeline([
          ('counts', FunctionTransformer(GloveVectorizer)),
          #('tf_idf', TfidfTransformer()),
         # ("zero",FunctionTransformer(replace_zero_values))
        ])),
        #('min',MinMaxScaler()),
   # ('in',SimpleImputer(strategy='mean')),
 # ('standard', StandardScaler(with_mean=False)),
  ('rl', LogisticRegression(max_iter=100000, penalty='l2'))])

param_grid_reglog = {
    #"ngram_tf_idf__counts__stop_words":('french',None), #TODO: pas de french : utiliser la liste de spacy ou nltk
    #"ngram_tf_idf__tf_idf__use_idf":(True,False),
    #"ngram_tf_idf__tf_idf__sublinear_tf":(True,False),
    "rl__class_weight":('balanced',None),
    #"rl__penalty": ('l1','l2'),
    "rl__multi_class":('auto','ovr','multinomial'),
    "rl__solver":('newton-cg', 'sag', 'saga','lbfgs','liblinear'), # 'newton-cholesky' -> à tester avec OneVs Rest
    "rl__C":(0.1,0.5,1.0) # complexité du modèle
    }

reglog = Classifieur(pipeline_reglog, param_grid_reglog)
liste_reglog.append(reglog)

# %% [markdown]
# ### Avec Word2VecVectorizer()

# %%
# liste de tuples nommés Classifieur(pipeline, param_grid)
liste_reglog = []
pipeline_reglog = Pipeline([
        ('ngram_tf_idf', Pipeline([
          ('counts', FunctionTransformer(w2vVectorizer)),
          #('tf_idf', TfidfTransformer())
        ])),
  #('standard', StandardScaler(with_mean=False)),
  ('rl',LogisticRegression(max_iter=100000 , penalty='l2'))])

param_grid_reglog = {
    #"ngram_tf_idf__counts__stop_words":('french',None), #TODO: pas de french : utiliser la liste de spacy ou nltk
    #"ngram_tf_idf__tf_idf__use_idf":(True,False),
    #"ngram_tf_idf__tf_idf__sublinear_tf":(True,False),
    #"rl__class_weight":('balanced',None),
    #"rl__penalty": ('l1','l2'),
    "rl__multi_class":('auto','ovr','multinomial'),
    "rl__solver":('newton-cg', 'sag', 'saga','lbfgs','liblinear'), # 'newton-cholesky' -> à tester avec OneVs Rest
    "rl__C":(0.1,0.5) # complexité du modèle
    }

reglog = Classifieur(pipeline_reglog, param_grid_reglog)
liste_reglog.append(reglog)

# %% [markdown]
# ### TEST

# %%
best_models_reglog = []

for (pipeline, param_grid) in liste_reglog:
    print("="*80)
    grid_search = GridSearchCV(pipeline, param_grid=param_grid,verbose=10)
    estimator = grid_search.fit(X_train_clean, y_train_bin)
    best_models_reglog.append(estimator)
    print("="*80,'\n')
# Out:
# ================================================================================
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [CV 1/5; 1/30] START rl__C=0.1, rl__multi_class=auto, rl__solver=newton-cg......
# [CV 1/5; 1/30] END rl__C=0.1, rl__multi_class=auto, rl__solver=newton-cg;, score=0.439 total time=  25.7s
# [CV 2/5; 1/30] START rl__C=0.1, rl__multi_class=auto, rl__solver=newton-cg......
# [CV 2/5; 1/30] END rl__C=0.1, rl__multi_class=auto, rl__solver=newton-cg;, score=0.422 total time=  26.1s
# [CV 3/5; 1/30] START rl__C=0.1, rl__multi_class=auto, rl__solver=newton-cg......
# [CV 3/5; 1/30] END rl__C=0.1, rl__multi_class=auto, rl__solver=newton-cg;, score=0.425 total time=  26.5s
# [CV 4/5; 1/30] START rl__C=0.1, rl__multi_class=auto, rl__solver=newton-cg......
# [CV 4/5; 1/30] END rl__C=0.1, rl__multi_class=auto, rl__solver=newton-cg;, score=0.426 total time=  28.0s
# [CV 5/5; 1/30] START rl__C=0.1, rl__multi_class=auto, rl__solver=newton-cg......
# [CV 5/5; 1/30] END rl__C=0.1, rl__multi_class=auto, rl__solver=newton-cg;, score=0.430 total time=  29.2s
# [CV 1/5; 2/30] START rl__C=0.1, rl__multi_class=auto, rl__solver=sag............
# [CV 1/5; 2/30] END rl__C=0.1, rl__multi_class=auto, rl__solver=sag;, score=0.439 total time=  36.1s
# [CV 2/5; 2/30] START rl__C=0.1, rl__multi_class=auto, rl__solver=sag............
# [CV 2/5; 2/30] END rl__C=0.1, rl__multi_class=auto, rl__solver=sag;, score=0.422 total time=  36.1s
# [CV 3/5; 2/30] START rl__C=0.1, rl__multi_class=auto, rl__solver=sag............
# [CV 3/5; 2/30] END rl__C=0.1, rl__multi_class=auto, rl__solver=sag;, score=0.425 total time=  40.2s
# [CV 4/5; 2/30] START rl__C=0.1, rl__multi_class=auto, rl__solver=sag............
# [CV 4/5; 2/30] END rl__C=0.1, rl__multi_class=auto, rl__solver=sag;, score=0.425 total time=  33.1s
# [CV 5/5; 2/30] START rl__C=0.1, rl__multi_class=auto, rl__solver=sag............
# [CV 5/5; 2/30] END rl__C=0.1, rl__multi_class=auto, rl__solver=sag;, score=0.430 total time=  38.8s
# [CV 1/5; 3/30] START rl__C=0.1, rl__multi_class=auto, rl__solver=saga...........
# [CV 1/5; 3/30] END rl__C=0.1, rl__multi_class=auto, rl__solver=saga;, score=0.439 total time=  56.2s
# [CV 2/5; 3/30] START rl__C=0.1, rl__multi_class=auto, rl__solver=saga...........
# [CV 2/5; 3/30] END rl__C=0.1, rl__multi_class=auto, rl__solver=saga;, score=0.423 total time=  55.2s
# [CV 3/5; 3/30] START rl__C=0.1, rl__multi_class=auto, rl__solver=saga...........
# [CV 3/5; 3/30] END rl__C=0.1, rl__multi_class=auto, rl__solver=saga;, score=0.425 total time= 1.1min
# [CV 4/5; 3/30] START rl__C=0.1, rl__multi_class=auto, rl__solver=saga...........
# [CV 4/5; 3/30] END rl__C=0.1, rl__multi_class=auto, rl__solver=saga;, score=0.425 total time=  48.8s
# [CV 5/5; 3/30] START rl__C=0.1, rl__multi_class=auto, rl__solver=saga...........
# [CV 5/5; 3/30] END rl__C=0.1, rl__multi_class=auto, rl__solver=saga;, score=0.429 total time=  56.5s
# [CV 1/5; 4/30] START rl__C=0.1, rl__multi_class=auto, rl__solver=lbfgs..........
# [CV 1/5; 4/30] END rl__C=0.1, rl__multi_class=auto, rl__solver=lbfgs;, score=0.439 total time=  25.1s
# [CV 2/5; 4/30] START rl__C=0.1, rl__multi_class=auto, rl__solver=lbfgs..........
# [CV 2/5; 4/30] END rl__C=0.1, rl__multi_class=auto, rl__solver=lbfgs;, score=0.423 total time=  24.7s
# [CV 3/5; 4/30] START rl__C=0.1, rl__multi_class=auto, rl__solver=lbfgs..........
# [CV 3/5; 4/30] END rl__C=0.1, rl__multi_class=auto, rl__solver=lbfgs;, score=0.425 total time=  25.0s
# [CV 4/5; 4/30] START rl__C=0.1, rl__multi_class=auto, rl__solver=lbfgs..........
# [CV 4/5; 4/30] END rl__C=0.1, rl__multi_class=auto, rl__solver=lbfgs;, score=0.426 total time=  25.2s
# [CV 5/5; 4/30] START rl__C=0.1, rl__multi_class=auto, rl__solver=lbfgs..........
# [CV 5/5; 4/30] END rl__C=0.1, rl__multi_class=auto, rl__solver=lbfgs;, score=0.430 total time=  25.1s
# [CV 1/5; 5/30] START rl__C=0.1, rl__multi_class=auto, rl__solver=liblinear......
# [CV 1/5; 5/30] END rl__C=0.1, rl__multi_class=auto, rl__solver=liblinear;, score=0.438 total time=  22.6s
# [CV 2/5; 5/30] START rl__C=0.1, rl__multi_class=auto, rl__solver=liblinear......
# [CV 2/5; 5/30] END rl__C=0.1, rl__multi_class=auto, rl__solver=liblinear;, score=0.422 total time=  22.4s
# [CV 3/5; 5/30] START rl__C=0.1, rl__multi_class=auto, rl__solver=liblinear......
# [CV 3/5; 5/30] END rl__C=0.1, rl__multi_class=auto, rl__solver=liblinear;, score=0.428 total time=  24.6s
# [CV 4/5; 5/30] START rl__C=0.1, rl__multi_class=auto, rl__solver=liblinear......
# [CV 4/5; 5/30] END rl__C=0.1, rl__multi_class=auto, rl__solver=liblinear;, score=0.426 total time=  22.3s
# [CV 5/5; 5/30] START rl__C=0.1, rl__multi_class=auto, rl__solver=liblinear......
# [CV 5/5; 5/30] END rl__C=0.1, rl__multi_class=auto, rl__solver=liblinear;, score=0.429 total time=  22.4s
# [CV 1/5; 6/30] START rl__C=0.1, rl__multi_class=ovr, rl__solver=newton-cg.......
# [CV 1/5; 6/30] END rl__C=0.1, rl__multi_class=ovr, rl__solver=newton-cg;, score=0.437 total time=  23.1s
# [CV 2/5; 6/30] START rl__C=0.1, rl__multi_class=ovr, rl__solver=newton-cg.......
# [CV 2/5; 6/30] END rl__C=0.1, rl__multi_class=ovr, rl__solver=newton-cg;, score=0.422 total time=  27.0s
# [CV 3/5; 6/30] START rl__C=0.1, rl__multi_class=ovr, rl__solver=newton-cg.......
# [CV 3/5; 6/30] END rl__C=0.1, rl__multi_class=ovr, rl__solver=newton-cg;, score=0.427 total time=  23.1s
# [CV 4/5; 6/30] START rl__C=0.1, rl__multi_class=ovr, rl__solver=newton-cg.......
# [CV 4/5; 6/30] END rl__C=0.1, rl__multi_class=ovr, rl__solver=newton-cg;, score=0.425 total time=  22.6s
# [CV 5/5; 6/30] START rl__C=0.1, rl__multi_class=ovr, rl__solver=newton-cg.......
# [CV 5/5; 6/30] END rl__C=0.1, rl__multi_class=ovr, rl__solver=newton-cg;, score=0.429 total time=  23.2s
# [CV 1/5; 7/30] START rl__C=0.1, rl__multi_class=ovr, rl__solver=sag.............
# [CV 1/5; 7/30] END rl__C=0.1, rl__multi_class=ovr, rl__solver=sag;, score=0.437 total time=  56.7s
# [CV 2/5; 7/30] START rl__C=0.1, rl__multi_class=ovr, rl__solver=sag.............
# [CV 2/5; 7/30] END rl__C=0.1, rl__multi_class=ovr, rl__solver=sag;, score=0.422 total time=  55.4s
# [CV 3/5; 7/30] START rl__C=0.1, rl__multi_class=ovr, rl__solver=sag.............
# [CV 3/5; 7/30] END rl__C=0.1, rl__multi_class=ovr, rl__solver=sag;, score=0.427 total time=  59.1s
# [CV 4/5; 7/30] START rl__C=0.1, rl__multi_class=ovr, rl__solver=sag.............
# [CV 4/5; 7/30] END rl__C=0.1, rl__multi_class=ovr, rl__solver=sag;, score=0.425 total time=  55.1s
# [CV 5/5; 7/30] START rl__C=0.1, rl__multi_class=ovr, rl__solver=sag.............
# [CV 5/5; 7/30] END rl__C=0.1, rl__multi_class=ovr, rl__solver=sag;, score=0.429 total time=  58.4s
# [CV 1/5; 8/30] START rl__C=0.1, rl__multi_class=ovr, rl__solver=saga............
# [CV 1/5; 8/30] END rl__C=0.1, rl__multi_class=ovr, rl__solver=saga;, score=0.437 total time= 1.5min
# [CV 2/5; 8/30] START rl__C=0.1, rl__multi_class=ovr, rl__solver=saga............
# [CV 2/5; 8/30] END rl__C=0.1, rl__multi_class=ovr, rl__solver=saga;, score=0.422 total time= 1.5min
# [CV 3/5; 8/30] START rl__C=0.1, rl__multi_class=ovr, rl__solver=saga............
# [CV 3/5; 8/30] END rl__C=0.1, rl__multi_class=ovr, rl__solver=saga;, score=0.427 total time= 1.5min
# [CV 4/5; 8/30] START rl__C=0.1, rl__multi_class=ovr, rl__solver=saga............
# [CV 4/5; 8/30] END rl__C=0.1, rl__multi_class=ovr, rl__solver=saga;, score=0.425 total time= 1.2min
# [CV 5/5; 8/30] START rl__C=0.1, rl__multi_class=ovr, rl__solver=saga............
# [CV 5/5; 8/30] END rl__C=0.1, rl__multi_class=ovr, rl__solver=saga;, score=0.429 total time= 1.5min
# [CV 1/5; 9/30] START rl__C=0.1, rl__multi_class=ovr, rl__solver=lbfgs...........
# [CV 1/5; 9/30] END rl__C=0.1, rl__multi_class=ovr, rl__solver=lbfgs;, score=0.438 total time=  20.2s
# [CV 2/5; 9/30] START rl__C=0.1, rl__multi_class=ovr, rl__solver=lbfgs...........
# [CV 2/5; 9/30] END rl__C=0.1, rl__multi_class=ovr, rl__solver=lbfgs;, score=0.421 total time=  20.6s
# [CV 3/5; 9/30] START rl__C=0.1, rl__multi_class=ovr, rl__solver=lbfgs...........
# [CV 3/5; 9/30] END rl__C=0.1, rl__multi_class=ovr, rl__solver=lbfgs;, score=0.427 total time=  22.1s
# [CV 4/5; 9/30] START rl__C=0.1, rl__multi_class=ovr, rl__solver=lbfgs...........
# [CV 4/5; 9/30] END rl__C=0.1, rl__multi_class=ovr, rl__solver=lbfgs;, score=0.425 total time=  24.6s
# [CV 5/5; 9/30] START rl__C=0.1, rl__multi_class=ovr, rl__solver=lbfgs...........
# [CV 5/5; 9/30] END rl__C=0.1, rl__multi_class=ovr, rl__solver=lbfgs;, score=0.429 total time=  20.6s
# [CV 1/5; 10/30] START rl__C=0.1, rl__multi_class=ovr, rl__solver=liblinear......
# [CV 1/5; 10/30] END rl__C=0.1, rl__multi_class=ovr, rl__solver=liblinear;, score=0.438 total time=  22.5s
# [CV 2/5; 10/30] START rl__C=0.1, rl__multi_class=ovr, rl__solver=liblinear......
# [CV 2/5; 10/30] END rl__C=0.1, rl__multi_class=ovr, rl__solver=liblinear;, score=0.422 total time=  22.6s
# [CV 3/5; 10/30] START rl__C=0.1, rl__multi_class=ovr, rl__solver=liblinear......
# [CV 3/5; 10/30] END rl__C=0.1, rl__multi_class=ovr, rl__solver=liblinear;, score=0.428 total time=  23.0s
# [CV 4/5; 10/30] START rl__C=0.1, rl__multi_class=ovr, rl__solver=liblinear......
# [CV 4/5; 10/30] END rl__C=0.1, rl__multi_class=ovr, rl__solver=liblinear;, score=0.426 total time=  22.5s
# [CV 5/5; 10/30] START rl__C=0.1, rl__multi_class=ovr, rl__solver=liblinear......
# [CV 5/5; 10/30] END rl__C=0.1, rl__multi_class=ovr, rl__solver=liblinear;, score=0.429 total time=  22.5s
# [CV 1/5; 11/30] START rl__C=0.1, rl__multi_class=multinomial, rl__solver=newton-cg
# [CV 1/5; 11/30] END rl__C=0.1, rl__multi_class=multinomial, rl__solver=newton-cg;, score=0.439 total time=  25.2s
# [CV 2/5; 11/30] START rl__C=0.1, rl__multi_class=multinomial, rl__solver=newton-cg
# [CV 2/5; 11/30] END rl__C=0.1, rl__multi_class=multinomial, rl__solver=newton-cg;, score=0.422 total time=  25.3s
# [CV 3/5; 11/30] START rl__C=0.1, rl__multi_class=multinomial, rl__solver=newton-cg
# [CV 3/5; 11/30] END rl__C=0.1, rl__multi_class=multinomial, rl__solver=newton-cg;, score=0.425 total time=  25.2s
# [CV 4/5; 11/30] START rl__C=0.1, rl__multi_class=multinomial, rl__solver=newton-cg
# [CV 4/5; 11/30] END rl__C=0.1, rl__multi_class=multinomial, rl__solver=newton-cg;, score=0.426 total time=  25.5s
# [CV 5/5; 11/30] START rl__C=0.1, rl__multi_class=multinomial, rl__solver=newton-cg
# [CV 5/5; 11/30] END rl__C=0.1, rl__multi_class=multinomial, rl__solver=newton-cg;, score=0.430 total time=  25.5s
# [CV 1/5; 12/30] START rl__C=0.1, rl__multi_class=multinomial, rl__solver=sag....
# [CV 1/5; 12/30] END rl__C=0.1, rl__multi_class=multinomial, rl__solver=sag;, score=0.439 total time=  37.8s
# [CV 2/5; 12/30] START rl__C=0.1, rl__multi_class=multinomial, rl__solver=sag....
# [CV 2/5; 12/30] END rl__C=0.1, rl__multi_class=multinomial, rl__solver=sag;, score=0.422 total time=  36.5s
# [CV 3/5; 12/30] START rl__C=0.1, rl__multi_class=multinomial, rl__solver=sag....
# [CV 3/5; 12/30] END rl__C=0.1, rl__multi_class=multinomial, rl__solver=sag;, score=0.425 total time=  41.4s
# [CV 4/5; 12/30] START rl__C=0.1, rl__multi_class=multinomial, rl__solver=sag....
# [CV 4/5; 12/30] END rl__C=0.1, rl__multi_class=multinomial, rl__solver=sag;, score=0.425 total time=  30.9s
# [CV 5/5; 12/30] START rl__C=0.1, rl__multi_class=multinomial, rl__solver=sag....
# [CV 5/5; 12/30] END rl__C=0.1, rl__multi_class=multinomial, rl__solver=sag;, score=0.430 total time=  36.6s
# [CV 1/5; 13/30] START rl__C=0.1, rl__multi_class=multinomial, rl__solver=saga...
# [CV 1/5; 13/30] END rl__C=0.1, rl__multi_class=multinomial, rl__solver=saga;, score=0.439 total time=  53.9s
# [CV 2/5; 13/30] START rl__C=0.1, rl__multi_class=multinomial, rl__solver=saga...
# [CV 2/5; 13/30] END rl__C=0.1, rl__multi_class=multinomial, rl__solver=saga;, score=0.423 total time=  53.8s
# [CV 3/5; 13/30] START rl__C=0.1, rl__multi_class=multinomial, rl__solver=saga...
# [CV 3/5; 13/30] END rl__C=0.1, rl__multi_class=multinomial, rl__solver=saga;, score=0.425 total time=  59.5s
# [CV 4/5; 13/30] START rl__C=0.1, rl__multi_class=multinomial, rl__solver=saga...
# [CV 4/5; 13/30] END rl__C=0.1, rl__multi_class=multinomial, rl__solver=saga;, score=0.425 total time=  45.3s
# [CV 5/5; 13/30] START rl__C=0.1, rl__multi_class=multinomial, rl__solver=saga...
# [CV 5/5; 13/30] END rl__C=0.1, rl__multi_class=multinomial, rl__solver=saga;, score=0.429 total time=  54.5s
# [CV 1/5; 14/30] START rl__C=0.1, rl__multi_class=multinomial, rl__solver=lbfgs..
# [CV 1/5; 14/30] END rl__C=0.1, rl__multi_class=multinomial, rl__solver=lbfgs;, score=0.439 total time=  26.8s
# [CV 2/5; 14/30] START rl__C=0.1, rl__multi_class=multinomial, rl__solver=lbfgs..
# [CV 2/5; 14/30] END rl__C=0.1, rl__multi_class=multinomial, rl__solver=lbfgs;, score=0.423 total time=  29.4s
# [CV 3/5; 14/30] START rl__C=0.1, rl__multi_class=multinomial, rl__solver=lbfgs..
# [CV 3/5; 14/30] END rl__C=0.1, rl__multi_class=multinomial, rl__solver=lbfgs;, score=0.425 total time=  25.8s
# [CV 4/5; 14/30] START rl__C=0.1, rl__multi_class=multinomial, rl__solver=lbfgs..
# [CV 4/5; 14/30] END rl__C=0.1, rl__multi_class=multinomial, rl__solver=lbfgs;, score=0.426 total time=  25.6s
# [CV 5/5; 14/30] START rl__C=0.1, rl__multi_class=multinomial, rl__solver=lbfgs..
# [CV 5/5; 14/30] END rl__C=0.1, rl__multi_class=multinomial, rl__solver=lbfgs;, score=0.430 total time=  25.6s
# [CV 1/5; 15/30] START rl__C=0.1, rl__multi_class=multinomial, rl__solver=liblinear
# [CV 1/5; 15/30] END rl__C=0.1, rl__multi_class=multinomial, rl__solver=liblinear;, score=nan total time=  13.3s
# [CV 2/5; 15/30] START rl__C=0.1, rl__multi_class=multinomial, rl__solver=liblinear
# [CV 2/5; 15/30] END rl__C=0.1, rl__multi_class=multinomial, rl__solver=liblinear;, score=nan total time=  15.2s
# [CV 3/5; 15/30] START rl__C=0.1, rl__multi_class=multinomial, rl__solver=liblinear
# [CV 3/5; 15/30] END rl__C=0.1, rl__multi_class=multinomial, rl__solver=liblinear;, score=nan total time=  13.2s
# [CV 4/5; 15/30] START rl__C=0.1, rl__multi_class=multinomial, rl__solver=liblinear
# [CV 4/5; 15/30] END rl__C=0.1, rl__multi_class=multinomial, rl__solver=liblinear;, score=nan total time=  13.4s
# [CV 5/5; 15/30] START rl__C=0.1, rl__multi_class=multinomial, rl__solver=liblinear
# [CV 5/5; 15/30] END rl__C=0.1, rl__multi_class=multinomial, rl__solver=liblinear;, score=nan total time=  13.4s
# [CV 1/5; 16/30] START rl__C=0.5, rl__multi_class=auto, rl__solver=newton-cg.....
# [CV 1/5; 16/30] END rl__C=0.5, rl__multi_class=auto, rl__solver=newton-cg;, score=0.438 total time=  27.9s
# [CV 2/5; 16/30] START rl__C=0.5, rl__multi_class=auto, rl__solver=newton-cg.....
# [CV 2/5; 16/30] END rl__C=0.5, rl__multi_class=auto, rl__solver=newton-cg;, score=0.421 total time=  28.9s
# [CV 3/5; 16/30] START rl__C=0.5, rl__multi_class=auto, rl__solver=newton-cg.....
# [CV 3/5; 16/30] END rl__C=0.5, rl__multi_class=auto, rl__solver=newton-cg;, score=0.425 total time=  28.5s
# [CV 4/5; 16/30] START rl__C=0.5, rl__multi_class=auto, rl__solver=newton-cg.....
# [CV 4/5; 16/30] END rl__C=0.5, rl__multi_class=auto, rl__solver=newton-cg;, score=0.427 total time=  28.6s
# [CV 5/5; 16/30] START rl__C=0.5, rl__multi_class=auto, rl__solver=newton-cg.....
# [CV 5/5; 16/30] END rl__C=0.5, rl__multi_class=auto, rl__solver=newton-cg;, score=0.428 total time=  29.4s
# [CV 1/5; 17/30] START rl__C=0.5, rl__multi_class=auto, rl__solver=sag...........
# [CV 1/5; 17/30] END rl__C=0.5, rl__multi_class=auto, rl__solver=sag;, score=0.438 total time=  52.2s
# [CV 2/5; 17/30] START rl__C=0.5, rl__multi_class=auto, rl__solver=sag...........
# [CV 2/5; 17/30] END rl__C=0.5, rl__multi_class=auto, rl__solver=sag;, score=0.421 total time=  58.9s
# [CV 3/5; 17/30] START rl__C=0.5, rl__multi_class=auto, rl__solver=sag...........
# [CV 3/5; 17/30] END rl__C=0.5, rl__multi_class=auto, rl__solver=sag;, score=0.425 total time=  58.5s
# [CV 4/5; 17/30] START rl__C=0.5, rl__multi_class=auto, rl__solver=sag...........
# [CV 4/5; 17/30] END rl__C=0.5, rl__multi_class=auto, rl__solver=sag;, score=0.427 total time=  47.8s
# [CV 5/5; 17/30] START rl__C=0.5, rl__multi_class=auto, rl__solver=sag...........
# [CV 5/5; 17/30] END rl__C=0.5, rl__multi_class=auto, rl__solver=sag;, score=0.428 total time=  55.7s
# [CV 1/5; 18/30] START rl__C=0.5, rl__multi_class=auto, rl__solver=saga..........
# [CV 1/5; 18/30] END rl__C=0.5, rl__multi_class=auto, rl__solver=saga;, score=0.438 total time=  56.1s
# [CV 2/5; 18/30] START rl__C=0.5, rl__multi_class=auto, rl__solver=saga..........
# [CV 2/5; 18/30] END rl__C=0.5, rl__multi_class=auto, rl__solver=saga;, score=0.421 total time= 1.1min
# [CV 3/5; 18/30] START rl__C=0.5, rl__multi_class=auto, rl__solver=saga..........
# [CV 3/5; 18/30] END rl__C=0.5, rl__multi_class=auto, rl__solver=saga;, score=0.425 total time= 1.4min
# [CV 4/5; 18/30] START rl__C=0.5, rl__multi_class=auto, rl__solver=saga..........
# [CV 4/5; 18/30] END rl__C=0.5, rl__multi_class=auto, rl__solver=saga;, score=0.427 total time= 1.3min
# [CV 5/5; 18/30] START rl__C=0.5, rl__multi_class=auto, rl__solver=saga..........
# [CV 5/5; 18/30] END rl__C=0.5, rl__multi_class=auto, rl__solver=saga;, score=0.428 total time= 1.3min
# [CV 1/5; 19/30] START rl__C=0.5, rl__multi_class=auto, rl__solver=lbfgs.........
# [CV 1/5; 19/30] END rl__C=0.5, rl__multi_class=auto, rl__solver=lbfgs;, score=0.438 total time=  29.2s
# [CV 2/5; 19/30] START rl__C=0.5, rl__multi_class=auto, rl__solver=lbfgs.........
# [CV 2/5; 19/30] END rl__C=0.5, rl__multi_class=auto, rl__solver=lbfgs;, score=0.421 total time=  30.9s
# [CV 3/5; 19/30] START rl__C=0.5, rl__multi_class=auto, rl__solver=lbfgs.........
# [CV 3/5; 19/30] END rl__C=0.5, rl__multi_class=auto, rl__solver=lbfgs;, score=0.424 total time=  29.0s
# [CV 4/5; 19/30] START rl__C=0.5, rl__multi_class=auto, rl__solver=lbfgs.........
# [CV 4/5; 19/30] END rl__C=0.5, rl__multi_class=auto, rl__solver=lbfgs;, score=0.426 total time=  29.2s
# [CV 5/5; 19/30] START rl__C=0.5, rl__multi_class=auto, rl__solver=lbfgs.........
# [CV 5/5; 19/30] END rl__C=0.5, rl__multi_class=auto, rl__solver=lbfgs;, score=0.428 total time=  29.7s
# [CV 1/5; 20/30] START rl__C=0.5, rl__multi_class=auto, rl__solver=liblinear.....
# [CV 1/5; 20/30] END rl__C=0.5, rl__multi_class=auto, rl__solver=liblinear;, score=0.436 total time=  24.6s
# [CV 2/5; 20/30] START rl__C=0.5, rl__multi_class=auto, rl__solver=liblinear.....
# [CV 2/5; 20/30] END rl__C=0.5, rl__multi_class=auto, rl__solver=liblinear;, score=0.423 total time=  24.3s
# [CV 3/5; 20/30] START rl__C=0.5, rl__multi_class=auto, rl__solver=liblinear.....
# [CV 3/5; 20/30] END rl__C=0.5, rl__multi_class=auto, rl__solver=liblinear;, score=0.428 total time=  24.9s
# [CV 4/5; 20/30] START rl__C=0.5, rl__multi_class=auto, rl__solver=liblinear.....
# [CV 4/5; 20/30] END rl__C=0.5, rl__multi_class=auto, rl__solver=liblinear;, score=0.424 total time=  24.8s
# [CV 5/5; 20/30] START rl__C=0.5, rl__multi_class=auto, rl__solver=liblinear.....
# [CV 5/5; 20/30] END rl__C=0.5, rl__multi_class=auto, rl__solver=liblinear;, score=0.428 total time=  26.8s
# [CV 1/5; 21/30] START rl__C=0.5, rl__multi_class=ovr, rl__solver=newton-cg......
# [CV 1/5; 21/30] END rl__C=0.5, rl__multi_class=ovr, rl__solver=newton-cg;, score=0.438 total time=  27.0s
# [CV 2/5; 21/30] START rl__C=0.5, rl__multi_class=ovr, rl__solver=newton-cg......
# [CV 2/5; 21/30] END rl__C=0.5, rl__multi_class=ovr, rl__solver=newton-cg;, score=0.424 total time=  24.9s
# [CV 3/5; 21/30] START rl__C=0.5, rl__multi_class=ovr, rl__solver=newton-cg......
# [CV 3/5; 21/30] END rl__C=0.5, rl__multi_class=ovr, rl__solver=newton-cg;, score=0.427 total time=  25.2s
# [CV 4/5; 21/30] START rl__C=0.5, rl__multi_class=ovr, rl__solver=newton-cg......
# [CV 4/5; 21/30] END rl__C=0.5, rl__multi_class=ovr, rl__solver=newton-cg;, score=0.424 total time=  25.5s
# [CV 5/5; 21/30] START rl__C=0.5, rl__multi_class=ovr, rl__solver=newton-cg......
# [CV 5/5; 21/30] END rl__C=0.5, rl__multi_class=ovr, rl__solver=newton-cg;, score=0.426 total time=  24.7s
# [CV 1/5; 22/30] START rl__C=0.5, rl__multi_class=ovr, rl__solver=sag............
# [CV 1/5; 22/30] END rl__C=0.5, rl__multi_class=ovr, rl__solver=sag;, score=0.438 total time= 1.6min
# [CV 2/5; 22/30] START rl__C=0.5, rl__multi_class=ovr, rl__solver=sag............
# [CV 2/5; 22/30] END rl__C=0.5, rl__multi_class=ovr, rl__solver=sag;, score=0.424 total time= 1.6min
# [CV 3/5; 22/30] START rl__C=0.5, rl__multi_class=ovr, rl__solver=sag............
# [CV 3/5; 22/30] END rl__C=0.5, rl__multi_class=ovr, rl__solver=sag;, score=0.427 total time= 1.7min
# [CV 4/5; 22/30] START rl__C=0.5, rl__multi_class=ovr, rl__solver=sag............
# [CV 4/5; 22/30] END rl__C=0.5, rl__multi_class=ovr, rl__solver=sag;, score=0.424 total time= 1.4min
# [CV 5/5; 22/30] START rl__C=0.5, rl__multi_class=ovr, rl__solver=sag............
# [CV 5/5; 22/30] END rl__C=0.5, rl__multi_class=ovr, rl__solver=sag;, score=0.426 total time= 1.7min
# [CV 1/5; 23/30] START rl__C=0.5, rl__multi_class=ovr, rl__solver=saga...........
# [CV 1/5; 23/30] END rl__C=0.5, rl__multi_class=ovr, rl__solver=saga;, score=0.438 total time= 2.6min
# [CV 2/5; 23/30] START rl__C=0.5, rl__multi_class=ovr, rl__solver=saga...........
# [CV 2/5; 23/30] END rl__C=0.5, rl__multi_class=ovr, rl__solver=saga;, score=0.424 total time= 2.3min
# [CV 3/5; 23/30] START rl__C=0.5, rl__multi_class=ovr, rl__solver=saga...........
# [CV 3/5; 23/30] END rl__C=0.5, rl__multi_class=ovr, rl__solver=saga;, score=0.427 total time= 2.6min
# [CV 4/5; 23/30] START rl__C=0.5, rl__multi_class=ovr, rl__solver=saga...........
# [CV 4/5; 23/30] END rl__C=0.5, rl__multi_class=ovr, rl__solver=saga;, score=0.424 total time= 2.0min
# [CV 5/5; 23/30] START rl__C=0.5, rl__multi_class=ovr, rl__solver=saga...........
# [CV 5/5; 23/30] END rl__C=0.5, rl__multi_class=ovr, rl__solver=saga;, score=0.426 total time= 2.4min
# [CV 1/5; 24/30] START rl__C=0.5, rl__multi_class=ovr, rl__solver=lbfgs..........
# [CV 1/5; 24/30] END rl__C=0.5, rl__multi_class=ovr, rl__solver=lbfgs;, score=0.438 total time=  24.7s
# [CV 2/5; 24/30] START rl__C=0.5, rl__multi_class=ovr, rl__solver=lbfgs..........
# [CV 2/5; 24/30] END rl__C=0.5, rl__multi_class=ovr, rl__solver=lbfgs;, score=0.424 total time=  25.0s
# [CV 3/5; 24/30] START rl__C=0.5, rl__multi_class=ovr, rl__solver=lbfgs..........
# [CV 3/5; 24/30] END rl__C=0.5, rl__multi_class=ovr, rl__solver=lbfgs;, score=0.428 total time=  29.4s
# [CV 4/5; 24/30] START rl__C=0.5, rl__multi_class=ovr, rl__solver=lbfgs..........
# [CV 4/5; 24/30] END rl__C=0.5, rl__multi_class=ovr, rl__solver=lbfgs;, score=0.424 total time=  26.4s
# [CV 5/5; 24/30] START rl__C=0.5, rl__multi_class=ovr, rl__solver=lbfgs..........
# [CV 5/5; 24/30] END rl__C=0.5, rl__multi_class=ovr, rl__solver=lbfgs;, score=0.426 total time=  25.7s
# [CV 1/5; 25/30] START rl__C=0.5, rl__multi_class=ovr, rl__solver=liblinear......
# [CV 1/5; 25/30] END rl__C=0.5, rl__multi_class=ovr, rl__solver=liblinear;, score=0.436 total time=  28.3s
# [CV 2/5; 25/30] START rl__C=0.5, rl__multi_class=ovr, rl__solver=liblinear......
# [CV 2/5; 25/30] END rl__C=0.5, rl__multi_class=ovr, rl__solver=liblinear;, score=0.423 total time=  27.7s
# [CV 3/5; 25/30] START rl__C=0.5, rl__multi_class=ovr, rl__solver=liblinear......
# [CV 3/5; 25/30] END rl__C=0.5, rl__multi_class=ovr, rl__solver=liblinear;, score=0.428 total time=  28.9s
# [CV 4/5; 25/30] START rl__C=0.5, rl__multi_class=ovr, rl__solver=liblinear......
# [CV 4/5; 25/30] END rl__C=0.5, rl__multi_class=ovr, rl__solver=liblinear;, score=0.424 total time=  28.0s
# [CV 5/5; 25/30] START rl__C=0.5, rl__multi_class=ovr, rl__solver=liblinear......
# [CV 5/5; 25/30] END rl__C=0.5, rl__multi_class=ovr, rl__solver=liblinear;, score=0.428 total time=  26.6s
# [CV 1/5; 26/30] START rl__C=0.5, rl__multi_class=multinomial, rl__solver=newton-cg
# [CV 1/5; 26/30] END rl__C=0.5, rl__multi_class=multinomial, rl__solver=newton-cg;, score=0.438 total time=  32.4s
# [CV 2/5; 26/30] START rl__C=0.5, rl__multi_class=multinomial, rl__solver=newton-cg
# [CV 2/5; 26/30] END rl__C=0.5, rl__multi_class=multinomial, rl__solver=newton-cg;, score=0.421 total time=  32.2s
# [CV 3/5; 26/30] START rl__C=0.5, rl__multi_class=multinomial, rl__solver=newton-cg
# [CV 3/5; 26/30] END rl__C=0.5, rl__multi_class=multinomial, rl__solver=newton-cg;, score=0.425 total time=  31.0s
# [CV 4/5; 26/30] START rl__C=0.5, rl__multi_class=multinomial, rl__solver=newton-cg
# [CV 4/5; 26/30] END rl__C=0.5, rl__multi_class=multinomial, rl__solver=newton-cg;, score=0.427 total time=  35.6s
# [CV 5/5; 26/30] START rl__C=0.5, rl__multi_class=multinomial, rl__solver=newton-cg
# [CV 5/5; 26/30] END rl__C=0.5, rl__multi_class=multinomial, rl__solver=newton-cg;, score=0.428 total time=  34.9s
# [CV 1/5; 27/30] START rl__C=0.5, rl__multi_class=multinomial, rl__solver=sag....
# [CV 1/5; 27/30] END rl__C=0.5, rl__multi_class=multinomial, rl__solver=sag;, score=0.438 total time=  58.5s
# [CV 2/5; 27/30] START rl__C=0.5, rl__multi_class=multinomial, rl__solver=sag....
# [CV 2/5; 27/30] END rl__C=0.5, rl__multi_class=multinomial, rl__solver=sag;, score=0.421 total time=  59.5s
# [CV 3/5; 27/30] START rl__C=0.5, rl__multi_class=multinomial, rl__solver=sag....
# [CV 3/5; 27/30] END rl__C=0.5, rl__multi_class=multinomial, rl__solver=sag;, score=0.425 total time= 1.0min
# [CV 4/5; 27/30] START rl__C=0.5, rl__multi_class=multinomial, rl__solver=sag....
# [CV 4/5; 27/30] END rl__C=0.5, rl__multi_class=multinomial, rl__solver=sag;, score=0.427 total time=  50.9s
# [CV 5/5; 27/30] START rl__C=0.5, rl__multi_class=multinomial, rl__solver=sag....
# [CV 5/5; 27/30] END rl__C=0.5, rl__multi_class=multinomial, rl__solver=sag;, score=0.428 total time= 1.1min
# [CV 1/5; 28/30] START rl__C=0.5, rl__multi_class=multinomial, rl__solver=saga...
# [CV 1/5; 28/30] END rl__C=0.5, rl__multi_class=multinomial, rl__solver=saga;, score=0.438 total time= 1.0min
# [CV 2/5; 28/30] START rl__C=0.5, rl__multi_class=multinomial, rl__solver=saga...
# [CV 2/5; 28/30] END rl__C=0.5, rl__multi_class=multinomial, rl__solver=saga;, score=0.421 total time= 1.1min
# [CV 3/5; 28/30] START rl__C=0.5, rl__multi_class=multinomial, rl__solver=saga...
# [CV 3/5; 28/30] END rl__C=0.5, rl__multi_class=multinomial, rl__solver=saga;, score=0.425 total time= 1.4min
# [CV 4/5; 28/30] START rl__C=0.5, rl__multi_class=multinomial, rl__solver=saga...
# [CV 4/5; 28/30] END rl__C=0.5, rl__multi_class=multinomial, rl__solver=saga;, score=0.427 total time= 1.3min
# [CV 5/5; 28/30] START rl__C=0.5, rl__multi_class=multinomial, rl__solver=saga...
# [CV 5/5; 28/30] END rl__C=0.5, rl__multi_class=multinomial, rl__solver=saga;, score=0.428 total time= 1.2min
# [CV 1/5; 29/30] START rl__C=0.5, rl__multi_class=multinomial, rl__solver=lbfgs..
# [CV 1/5; 29/30] END rl__C=0.5, rl__multi_class=multinomial, rl__solver=lbfgs;, score=0.438 total time=  31.7s
# [CV 2/5; 29/30] START rl__C=0.5, rl__multi_class=multinomial, rl__solver=lbfgs..
# [CV 2/5; 29/30] END rl__C=0.5, rl__multi_class=multinomial, rl__solver=lbfgs;, score=0.421 total time=  29.1s
# [CV 3/5; 29/30] START rl__C=0.5, rl__multi_class=multinomial, rl__solver=lbfgs..
# [CV 3/5; 29/30] END rl__C=0.5, rl__multi_class=multinomial, rl__solver=lbfgs;, score=0.424 total time=  29.4s
# [CV 4/5; 29/30] START rl__C=0.5, rl__multi_class=multinomial, rl__solver=lbfgs..
# [CV 4/5; 29/30] END rl__C=0.5, rl__multi_class=multinomial, rl__solver=lbfgs;, score=0.426 total time=  30.2s
# [CV 5/5; 29/30] START rl__C=0.5, rl__multi_class=multinomial, rl__solver=lbfgs..
# [CV 5/5; 29/30] END rl__C=0.5, rl__multi_class=multinomial, rl__solver=lbfgs;, score=0.428 total time=  30.0s
# [CV 1/5; 30/30] START rl__C=0.5, rl__multi_class=multinomial, rl__solver=liblinear
# [CV 1/5; 30/30] END rl__C=0.5, rl__multi_class=multinomial, rl__solver=liblinear;, score=nan total time=  13.9s
# [CV 2/5; 30/30] START rl__C=0.5, rl__multi_class=multinomial, rl__solver=liblinear
# [CV 2/5; 30/30] END rl__C=0.5, rl__multi_class=multinomial, rl__solver=liblinear;, score=nan total time=  17.4s
# [CV 3/5; 30/30] START rl__C=0.5, rl__multi_class=multinomial, rl__solver=liblinear
# [CV 3/5; 30/30] END rl__C=0.5, rl__multi_class=multinomial, rl__solver=liblinear;, score=nan total time=  13.7s
# [CV 4/5; 30/30] START rl__C=0.5, rl__multi_class=multinomial, rl__solver=liblinear
# [CV 4/5; 30/30] END rl__C=0.5, rl__multi_class=multinomial, rl__solver=liblinear;, score=nan total time=  13.8s
# [CV 5/5; 30/30] START rl__C=0.5, rl__multi_class=multinomial, rl__solver=liblinear
# [CV 5/5; 30/30] END rl__C=0.5, rl__multi_class=multinomial, rl__solver=liblinear;, score=nan total time=  15.7s
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 10 fits failed out of a total of 150.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/pipeline.py", line 394, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py", line 1519, in fit
#     multi_class = _check_multi_class(self.multi_class, solver, len(self.classes_))
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py", line 483, in _check_multi_class
#     raise ValueError("Solver %s does not support a multinomial backend." % solver)
# ValueError: Solver liblinear does not support a multinomial backend.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_search.py:969: UserWarning: One or more of the test scores are non-finite: [0.42844605 0.42829117 0.42829117 0.42844605 0.42865256 0.42777491
#  0.42782654 0.42798141 0.42782654 0.42865256 0.42844605 0.42829117
#  0.42829117 0.42844605        nan 0.42782654 0.42782654 0.42787816
#  0.42767166 0.42762003 0.42798141 0.42798141 0.42803304 0.42798141
#  0.42762003 0.42782654 0.42782654 0.42787816 0.42767166        nan]
#   warnings.warn(
# ================================================================================

# %%
from sklearn.metrics import classification_report
for model in best_models_reglog:
  clf = model
  y_pred = clf.predict(X_test_clean)
  print(classification_report(y_test_bin, y_pred))
  print("="*80)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.40      0.02      0.04      1339
#            1       0.58      0.49      0.53      1793
#            2       0.44      0.73      0.55      4571
#            3       0.39      0.36      0.38      3629
#            4       0.34      0.07      0.12      1585
#
#     accuracy                           0.44     12917
#    macro avg       0.43      0.33      0.32     12917
# weighted avg       0.43      0.44      0.39     12917
#
# ================================================================================

# %%
# Out:
# drive/  sample_data/
# /content/drive/MyDrive/saladier_vf
# glove_cvresults_all_knn.csv     w2v_cvresults_all_svm.gsheet
# glove_cvresults_all_knn.gsheet  word2vec_cvresults_all_knn.csv
# glove_cvresults_all_rdf.csv     word2vec_cvresults_all_knn.gsheet
# glove_cvresults_all_rdf.gsheet  word2vec_cvresults_all_rdf.csv
# glove_cvresults_all_svm.csv     word2vec_cvresults_all_rdf.gsheet
# w2v_cvresults_all_svm.csv

# %%
for clf, estimator in zip(['glove','word2vec'],best_models_reglog):
  pd_estimator = pd.DataFrame.from_dict(estimator.cv_results_)
  pd_estimator = pd_estimator.sort_values(by="rank_test_score",ascending=True)
  pd_estimator.to_csv(f"{clf}_cvresults_1000_logreg.csv")

# %%
print(len(y_test),len(y_pred))
# Out:
# 12917 12917

# %% [markdown]
# ## `Naives Bayes`

# %% [markdown]
# On ne peut pas utiliser NB avec Glove ou w2v. En plus, pas d'interet car les post traitement font perdre de la précision... tant pis...

# %%
from sklearn.preprocessing import MinMaxScaler, MaxAbsScaler #fixed import
from sklearn.decomposition import NMF
from sklearn.naive_bayes import CategoricalNB,MultinomialNB,GaussianNB, ComplementNB

# %% [markdown]
# ### Multinomial
# Seulement avec countvectorizer()

# %%
liste_mnb = []

# %% [markdown]
# #### Avec CountVectorizer()

# %%
# liste de tuples nommés Classifieur(pipeline, param_grid)
pipeline_mnb = Pipeline([
        ('ngram_tf_idf', Pipeline([
          ('counts', CountVectorizer()),
          ('tf_idf', TfidfTransformer()),
        ])),
  ('standard', StandardScaler(with_mean=False)),
  ('mnb', MultinomialNB())])

param_grid_mnb = {
    #"ngram_tf_idf__counts__stop_words":('french',None), #TODO: pas de french : utiliser la liste de spacy ou nltk
    "ngram_tf_idf__tf_idf__use_idf":(True,False),
    "ngram_tf_idf__tf_idf__sublinear_tf":(True,False),
    "mnb__fit_prior":(True,False),
    "mnb__alpha":[0.1, 1.0, 10.0] # complexité du modèle
    }

mnb = Classifieur(pipeline_mnb, param_grid_mnb)
liste_mnb.append(mnb)

# %% [markdown]
# #### Avec Glove -> solution ?

# %%
# liste de tuples nommés Classifieur(pipeline, param_grid)
pipeline_mnb = Pipeline([
        ('ngram_tf_idf', Pipeline([
          ('counts', FunctionTransformer(GloveVectorizer)),
          #('tf_idf', TfidfTransformer())
        ])),
  ("min",MinMaxScaler()),
  #('decomp', NMF()),
  ('mnb', MultinomialNB())])

param_grid_mnb = {
    #"ngram_tf_idf__counts__stop_words":('french',None), #TODO: pas de french : utiliser la liste de spacy ou nltk
    #"ngram_tf_idf__tf_idf__use_idf":(True,False),
    #"ngram_tf_idf__tf_idf__sublinear_tf":(True,False),
    "mnb__fit_prior":(True,False),
    "mnb__alpha":np.linspace(0.5, 1.5, 6) # complexité du modèle
    }

mnb = Classifieur(pipeline_mnb, param_grid_mnb)
liste_mnb.append(mnb)

# %% [markdown]
# #### Word2Vec

# %%
# liste de tuples nommés Classifieur(pipeline, param_grid)
pipeline_mnb = Pipeline([
        ('ngram_tf_idf', Pipeline([
          ('counts', FunctionTransformer(w2vVectorizer)),
          #('tf_idf', TfidfTransformer())
        ])),
  ("min",MinMaxScaler()),
  #('decomp', NMF()),
  ('mnb', MultinomialNB())])

param_grid_mnb = {
    #"ngram_tf_idf__counts__stop_words":('french',None), #TODO: pas de french : utiliser la liste de spacy ou nltk
    #"ngram_tf_idf__tf_idf__use_idf":(True,False),
    #"ngram_tf_idf__tf_idf__sublinear_tf":(True,False),
    "mnb__fit_prior":(True,False),
    "mnb__alpha":np.linspace(0.5, 1.5, 6) # complexité du modèle
    }

mnb = Classifieur(pipeline_mnb, param_grid_mnb)
liste_mnb.append(mnb)

# %% [markdown]
# ### GaussianNB
# #### CountVectorizer()

# %%
liste_mnb = []

# %%
# liste de tuples nommés Classifieur(pipeline, param_grid)
pipeline_mnb = Pipeline([
          ('counts', CountVectorizer()),
          #('tf_idf', TfidfTransformer()),
  ('standard', StandardScaler(with_mean=False)),
  ('mnb', GaussianNB())])

param_grid_mnb = {
    #"ngram_tf_idf__counts__stop_words":('french',None), #TODO: pas de french : utiliser la liste de spacy ou nltk
    #"tf_idf__use_idf":(True,False),
    #"tf_idf__sublinear_tf":(True,False),
    #"mnb__priors":([0.25, 0.75],None)
    "mnb__var_smoothing":(1e-9,1e-3)
    }


mnb = Classifieur(pipeline_mnb, param_grid_mnb)
liste_mnb.append(mnb)

vectorizer = CountVectorizer()
X = vectorizer.transform(X_train_clean)
clf = GaussianNB()
clf.fit(X.toarray())

# %%
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(X_train_clean)
clf = GaussianNB()
clf.fit(X.toarray(),y_train_bin)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-23672ef83045> in <module>
# ----> 1 vectorizer = CountVectorizer()
#       2 X = vectorizer.fit_transform(X_train_clean)
#       3 clf = GaussianNB()
#       4 clf.fit(X.toarray(),y_train_bin)
#
# NameError: name 'CountVectorizer' is not defined

# %%
Xc = vectorizer.fit_transform(X_test_clean)
y_pred = clf.predict(Xc)

# %% [markdown]
# #### Avec GloveVectorizer()

# %%
# liste de tuples nommés Classifieur(pipeline, param_grid)
pipeline_mnb = Pipeline([
        ('ngram_tf_idf', Pipeline([
          ('counts', FunctionTransformer(GloveVectorizer)),
          #('tf_idf', TfidfTransformer())
        ])),
  #('decomp', NMF()),
  ('mnb', GaussianNB())])

param_grid_mnb = {
    #"ngram_tf_idf__counts__stop_words":('french',None), #TODO: pas de french : utiliser la liste de spacy ou nltk
    #"ngram_tf_idf__tf_idf__use_idf":(True,False),
    #"ngram_tf_idf__tf_idf__sublinear_tf":(True,False),
    #"mnb__priors":([0.25, 0.75],None)
    "mnb__var_smoothing":(1e-9,1e-3)
    }

mnb = Classifieur(pipeline_mnb, param_grid_mnb)
liste_mnb.append(mnb)

# %% [markdown]
# #### Avec w2vVectorizer

# %%
# liste de tuples nommés Classifieur(pipeline, param_grid)
pipeline_mnb = Pipeline([
        ('ngram_tf_idf', Pipeline([
          ('counts', FunctionTransformer(w2vVectorizer)),
          #('tf_idf', TfidfTransformer())
        ])),
  #('decomp', NMF()),
  ('mnb', GaussianNB())])

param_grid_mnb = {
    #"ngram_tf_idf__counts__stop_words":('french',None), #TODO: pas de french : utiliser la liste de spacy ou nltk
    #"ngram_tf_idf__tf_idf__use_idf":(True,False),
    #"ngram_tf_idf__tf_idf__sublinear_tf":(True,False),
    #"mnb__priors":([0.25, 0.75],None)
    "mnb__var_smoothing":(1e-9,1e-3)
    }

mnb = Classifieur(pipeline_mnb, param_grid_mnb)
liste_mnb.append(mnb)

# %% [markdown]
# ### TEST

# %%
best_models_mnb = []

for (pipeline, param_grid) in liste_mnb:
    print("="*80)
    grid_search = GridSearchCV(pipeline, param_grid=param_grid,verbose=10)
    estimator = grid_search.fit(X_train_clean[:100], y_train_bin[:100])
    best_models_mnb.append(estimator)
    print("="*80,'\n')
# Out:
# ================================================================================
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV 1/5; 1/2] START mnb__var_smoothing=1e-09....................................
# [CV 1/5; 1/2] END .......mnb__var_smoothing=1e-09;, score=nan total time=   0.0s
# [CV 2/5; 1/2] START mnb__var_smoothing=1e-09....................................
# [CV 2/5; 1/2] END .......mnb__var_smoothing=1e-09;, score=nan total time=   0.0s
# [CV 3/5; 1/2] START mnb__var_smoothing=1e-09....................................
# [CV 3/5; 1/2] END .......mnb__var_smoothing=1e-09;, score=nan total time=   0.0s
# [CV 4/5; 1/2] START mnb__var_smoothing=1e-09....................................
# [CV 4/5; 1/2] END .......mnb__var_smoothing=1e-09;, score=nan total time=   0.0s
# [CV 5/5; 1/2] START mnb__var_smoothing=1e-09....................................
# [CV 5/5; 1/2] END .......mnb__var_smoothing=1e-09;, score=nan total time=   0.0s
# [CV 1/5; 2/2] START mnb__var_smoothing=0.001....................................
# [CV 1/5; 2/2] END .......mnb__var_smoothing=0.001;, score=nan total time=   0.0s
# [CV 2/5; 2/2] START mnb__var_smoothing=0.001....................................
# [CV 2/5; 2/2] END .......mnb__var_smoothing=0.001;, score=nan total time=   0.0s
# [CV 3/5; 2/2] START mnb__var_smoothing=0.001....................................
# [CV 3/5; 2/2] END .......mnb__var_smoothing=0.001;, score=nan total time=   0.0s
# [CV 4/5; 2/2] START mnb__var_smoothing=0.001....................................
# [CV 4/5; 2/2] END .......mnb__var_smoothing=0.001;, score=nan total time=   0.2s
# [CV 5/5; 2/2] START mnb__var_smoothing=0.001....................................
# [CV 5/5; 2/2] END .......mnb__var_smoothing=0.001;, score=nan total time=   0.0s
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 10 fits failed out of a total of 10.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/pipeline.py", line 394, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/naive_bayes.py", line 245, in fit
#     return self._partial_fit(
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/naive_bayes.py", line 402, in _partial_fit
#     X, y = self._validate_data(X, y, reset=first_call)
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py", line 964, in check_X_y
#     X = check_array(
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py", line 720, in check_array
#     array = _ensure_sparse_format(
#   File "/usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py", line 440, in _ensure_sparse_format
#     raise TypeError(
# TypeError: A sparse matrix was passed, but dense data is required. Use X.toarray() to convert to a dense numpy array.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_search.py:969: UserWarning: One or more of the test scores are non-finite: [nan nan]
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-112-5ac84272bfcb> in <module>
#       4     print("="*80)
#       5     grid_search = GridSearchCV(pipeline, param_grid=param_grid,verbose=10)
# ----> 6     estimator = grid_search.fit(X_train_clean[:100], y_train_bin[:100])
#       7     best_models_mnb.append(estimator)
#       8     print("="*80,'\n')
#
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     924             refit_start_time = time.time()
#     925             if y is not None:
# --> 926                 self.best_estimator_.fit(X, y, **fit_params)
#     927             else:
#     928                 self.best_estimator_.fit(X, **fit_params)
#
# /usr/local/lib/python3.8/dist-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     392             if self._final_estimator != "passthrough":
#     393                 fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 394                 self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     395
#     396         return self
#
# /usr/local/lib/python3.8/dist-packages/sklearn/naive_bayes.py in fit(self, X, y, sample_weight)
#     243         """
#     244         y = self._validate_data(y=y)
# --> 245         return self._partial_fit(
#     246             X, y, np.unique(y), _refit=True, sample_weight=sample_weight
#     247         )
#
# /usr/local/lib/python3.8/dist-packages/sklearn/naive_bayes.py in _partial_fit(self, X, y, classes, _refit, sample_weight)
#     400
#     401         first_call = _check_partial_fit_first_call(self, classes)
# --> 402         X, y = self._validate_data(X, y, reset=first_call)
#     403         if sample_weight is not None:
#     404             sample_weight = _check_sample_weight(sample_weight, X)
#
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
#     582             out = X, y
#     583
#
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     962         raise ValueError("y cannot be None")
#     963
# --> 964     X = check_array(
#     965         X,
#     966         accept_sparse=accept_sparse,
#
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     718     if sp.issparse(array):
#     719         _ensure_no_complex_data(array)
# --> 720         array = _ensure_sparse_format(
#     721             array,
#     722             accept_sparse=accept_sparse,
#
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py in _ensure_sparse_format(spmatrix, accept_sparse, dtype, copy, force_all_finite, accept_large_sparse)
#     438
#     439     if accept_sparse is False:
# --> 440         raise TypeError(
#     441             "A sparse matrix was passed, but dense "
#     442             "data is required. Use X.toarray() to "
#
# TypeError: A sparse matrix was passed, but dense data is required. Use X.toarray() to convert to a dense numpy array.

# %%
for model in best_models_mnb:
  clf = model
  y_pred = clf.predict(X_test_clean)
  print(classification_report(y_test_bin, y_pred))
  print("="*80)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.12      0.07      0.09      1339
#            1       0.28      0.48      0.36      1793
#            2       0.39      0.23      0.29      4571
#            3       0.31      0.28      0.29      3629
#            4       0.14      0.28      0.18      1585
#
#     accuracy                           0.27     12917
#    macro avg       0.25      0.27      0.24     12917
# weighted avg       0.29      0.27      0.26     12917
#
# ================================================================================
#               precision    recall  f1-score   support
#
#            0       0.13      0.02      0.04      1339
#            1       0.29      0.51      0.37      1793
#            2       0.41      0.25      0.31      4571
#            3       0.31      0.30      0.31      3629
#            4       0.14      0.28      0.18      1585
#
#     accuracy                           0.28     12917
#    macro avg       0.26      0.27      0.24     12917
# weighted avg       0.30      0.28      0.28     12917
#
# ================================================================================

# %%
for clf, estimator in zip(['glove','word2vec'],best_models_mnb):
  pd_estimator = pd.DataFrame.from_dict(estimator.cv_results_)
  pd_estimator =pd_estimator.sort_values(by="rank_test_score", ascending=True)
  pd_estimator.to_csv(f"{clf}GNB_cvresults_all.csv")

# %% [markdown]
# ## `Random Forest Classifier`

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
liste_rfc = []

# %% [markdown]
# ### Avec CountVectorizer

# %%
# liste de tuples nommés Classifieur(pipeline, param_grid)
pipeline_r = Pipeline([
        ('ngram_tf_idf', Pipeline([
          ('counts', CountVectorizer(min_df=1)),
          ('tf_idf', TfidfTransformer())
        ])),
  ('standard', StandardScaler(with_mean=False)),
  ('r', RandomForestClassifier())])

param_grid_r = {
    "ngram_tf_idf__counts__ngram_range": ((1, 1),(2,2)),  # unigrams or bigrams
    #"ngram_tf_idf__counts__stop_words":('french',None), #TODO: pas de french : utiliser la liste de spacy ou nltk
    "ngram_tf_idf__tf_idf__use_idf":(True,False),
    "ngram_tf_idf__tf_idf__use_idf":(True,False),
    "r__criterion":('gini', 'entropy'),
    "r__max_features":('sqrt', 'log2')
    }

r = Classifieur(pipeline_r, param_grid_r)
liste_rfc.append(r)

# %% [markdown]
# ### Avec GloveVectorizer

# %%
# liste de tuples nommés Classifieur(pipeline, param_grid)
pipeline_r = Pipeline([
        ('ngram_tf_idf', Pipeline([
          ('counts', FunctionTransformer(GloveVectorizer)),
          ('tf_idf', TfidfTransformer())
        ])),
  ('standard', StandardScaler(with_mean=False)),
  ('r', RandomForestClassifier())])

param_grid_r = {
    #"ngram_tf_idf__counts__stop_words":('french',None), #TODO: pas de french : utiliser la liste de spacy ou nltk
    "ngram_tf_idf__tf_idf__use_idf":(True,False),
    "ngram_tf_idf__tf_idf__use_idf":(True,False),
    "r__criterion":('gini', 'entropy'),
    "r__max_features":('sqrt', 'log2')
    }

r = Classifieur(pipeline_r, param_grid_r)
liste_rfc.append(r)

# %% [markdown]
# ### Avec w2vVectorizer

# %%
# liste de tuples nommés Classifieur(pipeline, param_grid)
pipeline_r = Pipeline([
        ('ngram_tf_idf', Pipeline([
          ('counts', FunctionTransformer(w2vVectorizer)),
          ('tf_idf', TfidfTransformer())
        ])),
  ('standard', StandardScaler(with_mean=False)),
  ('r',RandomForestClassifier())])

param_grid_reglog = {
    #"ngram_tf_idf__counts__stop_words":('french',None), #TODO: pas de french : utiliser la liste de spacy ou nltk
    "ngram_tf_idf__tf_idf__use_idf":(True,False),
    "ngram_tf_idf__tf_idf__use_idf":(True,False),
    "r__criterion":('gini', 'entropy'),
    "r__max_features":('sqrt', 'log2')
    }

r = Classifieur(pipeline_r, param_grid_r)
liste_rfc.append(r)

# %% [markdown]
# ### TEST

# %%
best_models_rtf = []

for (pipeline, param_grid) in liste_rfc:
    print("="*80)
    grid_search = GridSearchCV(pipeline, param_grid=param_grid,verbose=10)
    estimator = grid_search.fit(X_train_clean, y_train_bin)
    best_models_rtf.append(estimator)
    print("="*80,'\n')
# Out:
# ================================================================================
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [CV 1/5; 1/8] START ngram_tf_idf__tf_idf__use_idf=True, r__criterion=gini, r__max_features=sqrt
# [CV 1/5; 1/8] END ngram_tf_idf__tf_idf__use_idf=True, r__criterion=gini, r__max_features=sqrt;, score=0.394 total time=  59.5s
# [CV 2/5; 1/8] START ngram_tf_idf__tf_idf__use_idf=True, r__criterion=gini, r__max_features=sqrt
# [CV 2/5; 1/8] END ngram_tf_idf__tf_idf__use_idf=True, r__criterion=gini, r__max_features=sqrt;, score=0.390 total time=  59.2s
# [CV 3/5; 1/8] START ngram_tf_idf__tf_idf__use_idf=True, r__criterion=gini, r__max_features=sqrt
# [CV 3/5; 1/8] END ngram_tf_idf__tf_idf__use_idf=True, r__criterion=gini, r__max_features=sqrt;, score=0.390 total time= 1.2min
# [CV 4/5; 1/8] START ngram_tf_idf__tf_idf__use_idf=True, r__criterion=gini, r__max_features=sqrt
# [CV 4/5; 1/8] END ngram_tf_idf__tf_idf__use_idf=True, r__criterion=gini, r__max_features=sqrt;, score=0.390 total time=  59.3s
# [CV 5/5; 1/8] START ngram_tf_idf__tf_idf__use_idf=True, r__criterion=gini, r__max_features=sqrt
# [CV 5/5; 1/8] END ngram_tf_idf__tf_idf__use_idf=True, r__criterion=gini, r__max_features=sqrt;, score=0.380 total time= 1.1min
# [CV 1/5; 2/8] START ngram_tf_idf__tf_idf__use_idf=True, r__criterion=gini, r__max_features=log2
# [CV 1/5; 2/8] END ngram_tf_idf__tf_idf__use_idf=True, r__criterion=gini, r__max_features=log2;, score=0.382 total time=  49.6s
# [CV 2/5; 2/8] START ngram_tf_idf__tf_idf__use_idf=True, r__criterion=gini, r__max_features=log2
# [CV 2/5; 2/8] END ngram_tf_idf__tf_idf__use_idf=True, r__criterion=gini, r__max_features=log2;, score=0.375 total time=  46.7s
# [CV 3/5; 2/8] START ngram_tf_idf__tf_idf__use_idf=True, r__criterion=gini, r__max_features=log2
# [CV 3/5; 2/8] END ngram_tf_idf__tf_idf__use_idf=True, r__criterion=gini, r__max_features=log2;, score=0.386 total time=  48.9s
# [CV 4/5; 2/8] START ngram_tf_idf__tf_idf__use_idf=True, r__criterion=gini, r__max_features=log2
# [CV 4/5; 2/8] END ngram_tf_idf__tf_idf__use_idf=True, r__criterion=gini, r__max_features=log2;, score=0.378 total time=  53.2s
# [CV 5/5; 2/8] START ngram_tf_idf__tf_idf__use_idf=True, r__criterion=gini, r__max_features=log2
# [CV 5/5; 2/8] END ngram_tf_idf__tf_idf__use_idf=True, r__criterion=gini, r__max_features=log2;, score=0.378 total time=  47.8s
# [CV 1/5; 3/8] START ngram_tf_idf__tf_idf__use_idf=True, r__criterion=entropy, r__max_features=sqrt
# [CV 1/5; 3/8] END ngram_tf_idf__tf_idf__use_idf=True, r__criterion=entropy, r__max_features=sqrt;, score=0.386 total time= 1.4min
# [CV 2/5; 3/8] START ngram_tf_idf__tf_idf__use_idf=True, r__criterion=entropy, r__max_features=sqrt
# [CV 2/5; 3/8] END ngram_tf_idf__tf_idf__use_idf=True, r__criterion=entropy, r__max_features=sqrt;, score=0.385 total time= 1.4min
# [CV 3/5; 3/8] START ngram_tf_idf__tf_idf__use_idf=True, r__criterion=entropy, r__max_features=sqrt
# [CV 3/5; 3/8] END ngram_tf_idf__tf_idf__use_idf=True, r__criterion=entropy, r__max_features=sqrt;, score=0.386 total time= 1.4min
# [CV 4/5; 3/8] START ngram_tf_idf__tf_idf__use_idf=True, r__criterion=entropy, r__max_features=sqrt
# [CV 4/5; 3/8] END ngram_tf_idf__tf_idf__use_idf=True, r__criterion=entropy, r__max_features=sqrt;, score=0.383 total time= 1.4min
# [CV 5/5; 3/8] START ngram_tf_idf__tf_idf__use_idf=True, r__criterion=entropy, r__max_features=sqrt
# [CV 5/5; 3/8] END ngram_tf_idf__tf_idf__use_idf=True, r__criterion=entropy, r__max_features=sqrt;, score=0.383 total time= 1.4min
# [CV 1/5; 4/8] START ngram_tf_idf__tf_idf__use_idf=True, r__criterion=entropy, r__max_features=log2
# [CV 1/5; 4/8] END ngram_tf_idf__tf_idf__use_idf=True, r__criterion=entropy, r__max_features=log2;, score=0.387 total time= 1.1min
# [CV 2/5; 4/8] START ngram_tf_idf__tf_idf__use_idf=True, r__criterion=entropy, r__max_features=log2
# [CV 2/5; 4/8] END ngram_tf_idf__tf_idf__use_idf=True, r__criterion=entropy, r__max_features=log2;, score=0.389 total time= 1.1min
# [CV 3/5; 4/8] START ngram_tf_idf__tf_idf__use_idf=True, r__criterion=entropy, r__max_features=log2
# [CV 3/5; 4/8] END ngram_tf_idf__tf_idf__use_idf=True, r__criterion=entropy, r__max_features=log2;, score=0.393 total time= 1.1min
# [CV 4/5; 4/8] START ngram_tf_idf__tf_idf__use_idf=True, r__criterion=entropy, r__max_features=log2
# [CV 4/5; 4/8] END ngram_tf_idf__tf_idf__use_idf=True, r__criterion=entropy, r__max_features=log2;, score=0.387 total time= 1.1min
# [CV 5/5; 4/8] START ngram_tf_idf__tf_idf__use_idf=True, r__criterion=entropy, r__max_features=log2
# [CV 5/5; 4/8] END ngram_tf_idf__tf_idf__use_idf=True, r__criterion=entropy, r__max_features=log2;, score=0.385 total time= 1.1min
# [CV 1/5; 5/8] START ngram_tf_idf__tf_idf__use_idf=False, r__criterion=gini, r__max_features=sqrt
# [CV 1/5; 5/8] END ngram_tf_idf__tf_idf__use_idf=False, r__criterion=gini, r__max_features=sqrt;, score=0.391 total time=  58.8s
# [CV 2/5; 5/8] START ngram_tf_idf__tf_idf__use_idf=False, r__criterion=gini, r__max_features=sqrt
# [CV 2/5; 5/8] END ngram_tf_idf__tf_idf__use_idf=False, r__criterion=gini, r__max_features=sqrt;, score=0.390 total time=  58.1s
# [CV 3/5; 5/8] START ngram_tf_idf__tf_idf__use_idf=False, r__criterion=gini, r__max_features=sqrt
# [CV 3/5; 5/8] END ngram_tf_idf__tf_idf__use_idf=False, r__criterion=gini, r__max_features=sqrt;, score=0.393 total time= 1.0min
# [CV 4/5; 5/8] START ngram_tf_idf__tf_idf__use_idf=False, r__criterion=gini, r__max_features=sqrt
# [CV 4/5; 5/8] END ngram_tf_idf__tf_idf__use_idf=False, r__criterion=gini, r__max_features=sqrt;, score=0.383 total time=  59.4s
# [CV 5/5; 5/8] START ngram_tf_idf__tf_idf__use_idf=False, r__criterion=gini, r__max_features=sqrt
# [CV 5/5; 5/8] END ngram_tf_idf__tf_idf__use_idf=False, r__criterion=gini, r__max_features=sqrt;, score=0.399 total time=  58.4s
# [CV 1/5; 6/8] START ngram_tf_idf__tf_idf__use_idf=False, r__criterion=gini, r__max_features=log2
# [CV 1/5; 6/8] END ngram_tf_idf__tf_idf__use_idf=False, r__criterion=gini, r__max_features=log2;, score=0.393 total time=  50.0s
# [CV 2/5; 6/8] START ngram_tf_idf__tf_idf__use_idf=False, r__criterion=gini, r__max_features=log2
# [CV 2/5; 6/8] END ngram_tf_idf__tf_idf__use_idf=False, r__criterion=gini, r__max_features=log2;, score=0.384 total time=  48.5s
# [CV 3/5; 6/8] START ngram_tf_idf__tf_idf__use_idf=False, r__criterion=gini, r__max_features=log2
# [CV 3/5; 6/8] END ngram_tf_idf__tf_idf__use_idf=False, r__criterion=gini, r__max_features=log2;, score=0.389 total time=  47.3s
# [CV 4/5; 6/8] START ngram_tf_idf__tf_idf__use_idf=False, r__criterion=gini, r__max_features=log2
# [CV 4/5; 6/8] END ngram_tf_idf__tf_idf__use_idf=False, r__criterion=gini, r__max_features=log2;, score=0.384 total time=  47.6s
# [CV 5/5; 6/8] START ngram_tf_idf__tf_idf__use_idf=False, r__criterion=gini, r__max_features=log2
# [CV 5/5; 6/8] END ngram_tf_idf__tf_idf__use_idf=False, r__criterion=gini, r__max_features=log2;, score=0.388 total time=  50.1s
# [CV 1/5; 7/8] START ngram_tf_idf__tf_idf__use_idf=False, r__criterion=entropy, r__max_features=sqrt
# [CV 1/5; 7/8] END ngram_tf_idf__tf_idf__use_idf=False, r__criterion=entropy, r__max_features=sqrt;, score=0.391 total time= 1.4min
# [CV 2/5; 7/8] START ngram_tf_idf__tf_idf__use_idf=False, r__criterion=entropy, r__max_features=sqrt
# [CV 2/5; 7/8] END ngram_tf_idf__tf_idf__use_idf=False, r__criterion=entropy, r__max_features=sqrt;, score=0.384 total time= 1.4min
# [CV 3/5; 7/8] START ngram_tf_idf__tf_idf__use_idf=False, r__criterion=entropy, r__max_features=sqrt
# [CV 3/5; 7/8] END ngram_tf_idf__tf_idf__use_idf=False, r__criterion=entropy, r__max_features=sqrt;, score=0.391 total time= 1.4min
# [CV 4/5; 7/8] START ngram_tf_idf__tf_idf__use_idf=False, r__criterion=entropy, r__max_features=sqrt
# [CV 4/5; 7/8] END ngram_tf_idf__tf_idf__use_idf=False, r__criterion=entropy, r__max_features=sqrt;, score=0.389 total time= 1.4min
# [CV 5/5; 7/8] START ngram_tf_idf__tf_idf__use_idf=False, r__criterion=entropy, r__max_features=sqrt
# [CV 5/5; 7/8] END ngram_tf_idf__tf_idf__use_idf=False, r__criterion=entropy, r__max_features=sqrt;, score=0.385 total time= 1.4min
# [CV 1/5; 8/8] START ngram_tf_idf__tf_idf__use_idf=False, r__criterion=entropy, r__max_features=log2
# [CV 1/5; 8/8] END ngram_tf_idf__tf_idf__use_idf=False, r__criterion=entropy, r__max_features=log2;, score=0.396 total time= 1.1min
# [CV 2/5; 8/8] START ngram_tf_idf__tf_idf__use_idf=False, r__criterion=entropy, r__max_features=log2
# [CV 2/5; 8/8] END ngram_tf_idf__tf_idf__use_idf=False, r__criterion=entropy, r__max_features=log2;, score=0.389 total time= 1.1min
# [CV 3/5; 8/8] START ngram_tf_idf__tf_idf__use_idf=False, r__criterion=entropy, r__max_features=log2
# [CV 3/5; 8/8] END ngram_tf_idf__tf_idf__use_idf=False, r__criterion=entropy, r__max_features=log2;, score=0.394 total time= 1.1min
# [CV 4/5; 8/8] START ngram_tf_idf__tf_idf__use_idf=False, r__criterion=entropy, r__max_features=log2
# [CV 4/5; 8/8] END ngram_tf_idf__tf_idf__use_idf=False, r__criterion=entropy, r__max_features=log2;, score=0.385 total time= 1.1min
# [CV 5/5; 8/8] START ngram_tf_idf__tf_idf__use_idf=False, r__criterion=entropy, r__max_features=log2
# [CV 5/5; 8/8] END ngram_tf_idf__tf_idf__use_idf=False, r__criterion=entropy, r__max_features=log2;, score=0.379 total time= 1.1min
# ================================================================================
#
# ================================================================================
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [CV 1/5; 1/8] START ngram_tf_idf__tf_idf__use_idf=True, r__criterion=gini, r__max_features=sqrt
# [CV 1/5; 1/8] END ngram_tf_idf__tf_idf__use_idf=True, r__criterion=gini, r__max_features=sqrt;, score=0.413 total time= 1.9min
# [CV 2/5; 1/8] START ngram_tf_idf__tf_idf__use_idf=True, r__criterion=gini, r__max_features=sqrt
# [CV 2/5; 1/8] END ngram_tf_idf__tf_idf__use_idf=True, r__criterion=gini, r__max_features=sqrt;, score=0.404 total time= 1.9min
# [CV 3/5; 1/8] START ngram_tf_idf__tf_idf__use_idf=True, r__criterion=gini, r__max_features=sqrt
# [CV 3/5; 1/8] END ngram_tf_idf__tf_idf__use_idf=True, r__criterion=gini, r__max_features=sqrt;, score=0.413 total time= 1.9min
# [CV 4/5; 1/8] START ngram_tf_idf__tf_idf__use_idf=True, r__criterion=gini, r__max_features=sqrt
# [CV 4/5; 1/8] END ngram_tf_idf__tf_idf__use_idf=True, r__criterion=gini, r__max_features=sqrt;, score=0.414 total time= 1.8min
# [CV 5/5; 1/8] START ngram_tf_idf__tf_idf__use_idf=True, r__criterion=gini, r__max_features=sqrt
# [CV 5/5; 1/8] END ngram_tf_idf__tf_idf__use_idf=True, r__criterion=gini, r__max_features=sqrt;, score=0.412 total time= 1.9min
# [CV 1/5; 2/8] START ngram_tf_idf__tf_idf__use_idf=True, r__criterion=gini, r__max_features=log2
# [CV 1/5; 2/8] END ngram_tf_idf__tf_idf__use_idf=True, r__criterion=gini, r__max_features=log2;, score=0.408 total time= 1.1min
# [CV 2/5; 2/8] START ngram_tf_idf__tf_idf__use_idf=True, r__criterion=gini, r__max_features=log2
# [CV 2/5; 2/8] END ngram_tf_idf__tf_idf__use_idf=True, r__criterion=gini, r__max_features=log2;, score=0.412 total time= 1.2min
# [CV 3/5; 2/8] START ngram_tf_idf__tf_idf__use_idf=True, r__criterion=gini, r__max_features=log2
# [CV 3/5; 2/8] END ngram_tf_idf__tf_idf__use_idf=True, r__criterion=gini, r__max_features=log2;, score=0.419 total time= 1.1min
# [CV 4/5; 2/8] START ngram_tf_idf__tf_idf__use_idf=True, r__criterion=gini, r__max_features=log2
# [CV 4/5; 2/8] END ngram_tf_idf__tf_idf__use_idf=True, r__criterion=gini, r__max_features=log2;, score=0.408 total time= 1.1min
# [CV 5/5; 2/8] START ngram_tf_idf__tf_idf__use_idf=True, r__criterion=gini, r__max_features=log2
# [CV 5/5; 2/8] END ngram_tf_idf__tf_idf__use_idf=True, r__criterion=gini, r__max_features=log2;, score=0.406 total time= 1.2min
# [CV 1/5; 3/8] START ngram_tf_idf__tf_idf__use_idf=True, r__criterion=entropy, r__max_features=sqrt
# [CV 1/5; 3/8] END ngram_tf_idf__tf_idf__use_idf=True, r__criterion=entropy, r__max_features=sqrt;, score=0.422 total time= 2.5min
# [CV 2/5; 3/8] START ngram_tf_idf__tf_idf__use_idf=True, r__criterion=entropy, r__max_features=sqrt
# [CV 2/5; 3/8] END ngram_tf_idf__tf_idf__use_idf=True, r__criterion=entropy, r__max_features=sqrt;, score=0.413 total time= 2.5min
# [CV 3/5; 3/8] START ngram_tf_idf__tf_idf__use_idf=True, r__criterion=entropy, r__max_features=sqrt
# [CV 3/5; 3/8] END ngram_tf_idf__tf_idf__use_idf=True, r__criterion=entropy, r__max_features=sqrt;, score=0.411 total time= 2.5min
# [CV 4/5; 3/8] START ngram_tf_idf__tf_idf__use_idf=True, r__criterion=entropy, r__max_features=sqrt
# [CV 4/5; 3/8] END ngram_tf_idf__tf_idf__use_idf=True, r__criterion=entropy, r__max_features=sqrt;, score=0.400 total time= 2.5min
# [CV 5/5; 3/8] START ngram_tf_idf__tf_idf__use_idf=True, r__criterion=entropy, r__max_features=sqrt
# [CV 5/5; 3/8] END ngram_tf_idf__tf_idf__use_idf=True, r__criterion=entropy, r__max_features=sqrt;, score=0.409 total time= 2.5min
# [CV 1/5; 4/8] START ngram_tf_idf__tf_idf__use_idf=True, r__criterion=entropy, r__max_features=log2
# [CV 1/5; 4/8] END ngram_tf_idf__tf_idf__use_idf=True, r__criterion=entropy, r__max_features=log2;, score=0.409 total time= 1.5min
# [CV 2/5; 4/8] START ngram_tf_idf__tf_idf__use_idf=True, r__criterion=entropy, r__max_features=log2
# [CV 2/5; 4/8] END ngram_tf_idf__tf_idf__use_idf=True, r__criterion=entropy, r__max_features=log2;, score=0.397 total time= 1.5min
# [CV 3/5; 4/8] START ngram_tf_idf__tf_idf__use_idf=True, r__criterion=entropy, r__max_features=log2
# [CV 3/5; 4/8] END ngram_tf_idf__tf_idf__use_idf=True, r__criterion=entropy, r__max_features=log2;, score=0.414 total time= 1.5min
# [CV 4/5; 4/8] START ngram_tf_idf__tf_idf__use_idf=True, r__criterion=entropy, r__max_features=log2
# [CV 4/5; 4/8] END ngram_tf_idf__tf_idf__use_idf=True, r__criterion=entropy, r__max_features=log2;, score=0.403 total time= 1.5min
# [CV 5/5; 4/8] START ngram_tf_idf__tf_idf__use_idf=True, r__criterion=entropy, r__max_features=log2
# [CV 5/5; 4/8] END ngram_tf_idf__tf_idf__use_idf=True, r__criterion=entropy, r__max_features=log2;, score=0.405 total time= 1.5min
# [CV 1/5; 5/8] START ngram_tf_idf__tf_idf__use_idf=False, r__criterion=gini, r__max_features=sqrt
# [CV 1/5; 5/8] END ngram_tf_idf__tf_idf__use_idf=False, r__criterion=gini, r__max_features=sqrt;, score=0.413 total time= 1.9min
# [CV 2/5; 5/8] START ngram_tf_idf__tf_idf__use_idf=False, r__criterion=gini, r__max_features=sqrt
# [CV 2/5; 5/8] END ngram_tf_idf__tf_idf__use_idf=False, r__criterion=gini, r__max_features=sqrt;, score=0.409 total time= 1.8min
# [CV 3/5; 5/8] START ngram_tf_idf__tf_idf__use_idf=False, r__criterion=gini, r__max_features=sqrt
# [CV 3/5; 5/8] END ngram_tf_idf__tf_idf__use_idf=False, r__criterion=gini, r__max_features=sqrt;, score=0.416 total time= 1.9min
# [CV 4/5; 5/8] START ngram_tf_idf__tf_idf__use_idf=False, r__criterion=gini, r__max_features=sqrt
# [CV 4/5; 5/8] END ngram_tf_idf__tf_idf__use_idf=False, r__criterion=gini, r__max_features=sqrt;, score=0.413 total time= 1.9min
# [CV 5/5; 5/8] START ngram_tf_idf__tf_idf__use_idf=False, r__criterion=gini, r__max_features=sqrt
# [CV 5/5; 5/8] END ngram_tf_idf__tf_idf__use_idf=False, r__criterion=gini, r__max_features=sqrt;, score=0.416 total time= 1.9min
# [CV 1/5; 6/8] START ngram_tf_idf__tf_idf__use_idf=False, r__criterion=gini, r__max_features=log2
# [CV 1/5; 6/8] END ngram_tf_idf__tf_idf__use_idf=False, r__criterion=gini, r__max_features=log2;, score=0.411 total time= 1.2min
# [CV 2/5; 6/8] START ngram_tf_idf__tf_idf__use_idf=False, r__criterion=gini, r__max_features=log2
# [CV 2/5; 6/8] END ngram_tf_idf__tf_idf__use_idf=False, r__criterion=gini, r__max_features=log2;, score=0.410 total time= 1.2min
# [CV 3/5; 6/8] START ngram_tf_idf__tf_idf__use_idf=False, r__criterion=gini, r__max_features=log2
# [CV 3/5; 6/8] END ngram_tf_idf__tf_idf__use_idf=False, r__criterion=gini, r__max_features=log2;, score=0.415 total time= 1.1min
# [CV 4/5; 6/8] START ngram_tf_idf__tf_idf__use_idf=False, r__criterion=gini, r__max_features=log2
# [CV 4/5; 6/8] END ngram_tf_idf__tf_idf__use_idf=False, r__criterion=gini, r__max_features=log2;, score=0.407 total time= 1.2min
# [CV 5/5; 6/8] START ngram_tf_idf__tf_idf__use_idf=False, r__criterion=gini, r__max_features=log2
# [CV 5/5; 6/8] END ngram_tf_idf__tf_idf__use_idf=False, r__criterion=gini, r__max_features=log2;, score=0.396 total time= 1.2min
# [CV 1/5; 7/8] START ngram_tf_idf__tf_idf__use_idf=False, r__criterion=entropy, r__max_features=sqrt
# [CV 1/5; 7/8] END ngram_tf_idf__tf_idf__use_idf=False, r__criterion=entropy, r__max_features=sqrt;, score=0.422 total time= 2.6min
# [CV 2/5; 7/8] START ngram_tf_idf__tf_idf__use_idf=False, r__criterion=entropy, r__max_features=sqrt
# [CV 2/5; 7/8] END ngram_tf_idf__tf_idf__use_idf=False, r__criterion=entropy, r__max_features=sqrt;, score=0.410 total time= 2.5min
# [CV 3/5; 7/8] START ngram_tf_idf__tf_idf__use_idf=False, r__criterion=entropy, r__max_features=sqrt
# [CV 3/5; 7/8] END ngram_tf_idf__tf_idf__use_idf=False, r__criterion=entropy, r__max_features=sqrt;, score=0.412 total time= 2.5min
# [CV 4/5; 7/8] START ngram_tf_idf__tf_idf__use_idf=False, r__criterion=entropy, r__max_features=sqrt
# [CV 4/5; 7/8] END ngram_tf_idf__tf_idf__use_idf=False, r__criterion=entropy, r__max_features=sqrt;, score=0.412 total time= 2.5min
# [CV 5/5; 7/8] START ngram_tf_idf__tf_idf__use_idf=False, r__criterion=entropy, r__max_features=sqrt
# [CV 5/5; 7/8] END ngram_tf_idf__tf_idf__use_idf=False, r__criterion=entropy, r__max_features=sqrt;, score=0.407 total time= 2.5min
# [CV 1/5; 8/8] START ngram_tf_idf__tf_idf__use_idf=False, r__criterion=entropy, r__max_features=log2
# [CV 1/5; 8/8] END ngram_tf_idf__tf_idf__use_idf=False, r__criterion=entropy, r__max_features=log2;, score=0.418 total time= 1.5min
# [CV 2/5; 8/8] START ngram_tf_idf__tf_idf__use_idf=False, r__criterion=entropy, r__max_features=log2
# [CV 2/5; 8/8] END ngram_tf_idf__tf_idf__use_idf=False, r__criterion=entropy, r__max_features=log2;, score=0.409 total time= 1.5min
# [CV 3/5; 8/8] START ngram_tf_idf__tf_idf__use_idf=False, r__criterion=entropy, r__max_features=log2
# [CV 3/5; 8/8] END ngram_tf_idf__tf_idf__use_idf=False, r__criterion=entropy, r__max_features=log2;, score=0.409 total time= 1.6min
# [CV 4/5; 8/8] START ngram_tf_idf__tf_idf__use_idf=False, r__criterion=entropy, r__max_features=log2
# [CV 4/5; 8/8] END ngram_tf_idf__tf_idf__use_idf=False, r__criterion=entropy, r__max_features=log2;, score=0.404 total time= 1.5min
# [CV 5/5; 8/8] START ngram_tf_idf__tf_idf__use_idf=False, r__criterion=entropy, r__max_features=log2
# [CV 5/5; 8/8] END ngram_tf_idf__tf_idf__use_idf=False, r__criterion=entropy, r__max_features=log2;, score=0.404 total time= 1.5min
# ================================================================================

# %%
for m in best_models_rtf:
  y_pred = m.predict(X_test_clean)
  print(classification_report(y_test_bin, y_pred))
  print("="*80)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.61      0.76      1339
#            1       0.85      0.73      0.78      1793
#            2       0.66      0.89      0.76      4571
#            3       0.76      0.71      0.74      3629
#            4       0.99      0.61      0.76      1585
#
#     accuracy                           0.75     12917
#    macro avg       0.85      0.71      0.76     12917
# weighted avg       0.79      0.75      0.75     12917
#
# ================================================================================
#               precision    recall  f1-score   support
#
#            0       1.00      0.61      0.76      1339
#            1       0.87      0.75      0.81      1793
#            2       0.67      0.91      0.77      4571
#            3       0.78      0.72      0.75      3629
#            4       0.99      0.62      0.76      1585
#
#     accuracy                           0.77     12917
#    macro avg       0.86      0.72      0.77     12917
# weighted avg       0.80      0.77      0.77     12917
#
# ================================================================================

# %%
for clf, estimator in zip(['glove','word2vec'],best_models_rtf):
  pd_estimator = pd.DataFrame.from_dict(estimator.cv_results_)
  pd_estimator = pd_estimator.sort_values(by="rank_test_score",ascending=True)
  pd_estimator.to_csv(f"{clf}_cvresults_all_rdf.csv")

# %% [markdown]
# # Visualisation des résultats

# %% [markdown]
# - `predict_proba` donne une liste de probabilité
# - `clf.classes_` donne les étiquettes des classes (pour qu'on récupère l'ordre)
#
# Les colonnes qu'on veut dans notre dataframe récapitulatif :
#
# - le nom du classifieur
# - `estimator.best_params_` = les paramètres sous forme de dictionnaire du meilleur modèle trouvé avec le gridsearch
# - `estimator.best_estimator_` = la pipeline du meilleur modèle
# - `estimator.best_score_` = le mean_test_score du meilleur modèle trouvé avec le gridsearch

# %% [markdown]
# ## Sortie de figure / plot
#
# On sort les figures du meilleur classifieur

# %%
from sklearn.pipeline import make_pipeline

# %%
pipe = make_pipeline(CountVectorizer(min_df=1, ngram_range=(1,1)),TfidfTransformer(),LogisticRegression(max_iter=10000,multi_class="ovr"))
pipe.fit(X_train_clean, y_train_bin)
y_pred = clf.predict(X_test_clean)
print(classification_report(y_test_bin,y_pred))

# %% [markdown]
# ### Learning Curve

# %%
from sklearn.model_selection import learning_curve
import matplotlib.pyplot as plt

# Utilisez la fonction learning_curve pour obtenir les scores de formation et de validation pour différentes tailles d'ensemble de données
train_sizes, train_scores, validation_scores = learning_curve(pipe, X_train_clean, y_train_bin, cv=5)

# %%
test_scores = validation_scores

# Calcul des moyennes et écart-types pour chaque point de la courbe
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

# Tracé de la courbe
plt.figure()
plt.title("Regression Logistique")
plt.xlabel("Taille de l'ensemble d'entraînement")
plt.ylabel("Score")
plt.ylim(0.0, 1.1)
plt.fill_between(train_sizes, train_scores_mean - train_scores_std, train_scores_mean + train_scores_std, alpha=0.1, color="r")
plt.fill_between(train_sizes, test_scores_mean - test_scores_std, test_scores_mean + test_scores_std, alpha=0.1, color="g")
plt.plot(train_sizes, train_scores_mean, 'o-', color="r", label="Score de l'ensemble d'entraînement")
plt.plot(train_sizes, test_scores_mean, 'o-', color="g", label="Score de l'ensemble de test")

plt.legend(loc="best")
plt.savefig("PlusjoliLearningCurve.png")
plt.show()

# %% [markdown]
# ### Matrice de confusion

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay
clf = LogisticRegression()
fig, ax = plt.subplots(figsize=(10, 5))
ConfusionMatrixDisplay.from_predictions(y_test_bin, y_pred, ax=ax, normalize='true')
ax.xaxis.set_ticklabels(np.array(['ELDR', 'GUE-NGL', 'PPE-DE', 'PSE', 'Verts-ALE']))
ax.yaxis.set_ticklabels(np.array(['ELDR', 'GUE-NGL', 'PPE-DE', 'PSE', 'Verts-ALE']))
_ = ax.set_title(
    f"Confusion Matrix for {clf.__class__.__name__}\non the original documents"
)

# %% [markdown]
# # Expérience avec FastText
#
# Quelques test effectués avec FastText. On ne l'a utilisé que sur les meilleurs modèles car le temps de chargement des vecteurs est relativement long.

# %%
pipeline_svm = Pipeline([
          ('counts', FunctionTransformer(FTVectorizer)),
          ('svm', LinearSVC(class_weight='balanced',max_iter=10000,C=0.1))
                        ])

pipeline_svm.fit(X_train_clean,y_train_bin)

# %%
pipeline_r = Pipeline([
        ('ngram_tf_idf', Pipeline([
          ('counts', FunctionTransformer(FTVectorizer)),
          ('tf_idf', TfidfTransformer(use_idf=False))
        ])),
  ('standard', StandardScaler(with_mean=False)),
  ('r',RandomForestClassifier(criterion='gini',max_features='sqrt'))])

pipeline_r.fit(X_train_clean,y_train_bin)
y_pred = pipeline_r.predict(X_test_clean)
print(classification_report(y_test_bin, y_pred))

# %%
pipeline_knn = Pipeline([
        ('ngram_tf_idf', Pipeline([
          ('counts', FunctionTransformer(FTVectorizer)),
          ('tf_idf', TfidfTransformer(use_idf = False))
        ])),
    ('select',SelectKBest(k=20)),
  ('knn', KNeighborsClassifier(algorithm='auto',n_neighbors=5,))])

pipeline_knn.fit(X_train_clean,y_train_bin)
ypred = pipeline_knn.predict(X_test_clean)
print(classification_report(y_test_bin, y_pred))

# %%
pipeline_reglog = Pipeline([
  ('counts', FunctionTransformer(FTVectorizer)),
  ('standard', StandardScaler(with_mean=False)),
  ('rl',LogisticRegression(max_iter=100000 , penalty='l2',solver="liblinear",multi_class="ovr",C=0.1))

])

pipeline_reglog.fit(X_train_clean,y_train_bin)
y_pred = pipeline_reglog.predict(X_test_clean)
print(classification_report(y_test_bin,y_pred))
